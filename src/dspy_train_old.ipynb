# %% [markdown]
# ## DSPy train/eval
#
# Note: I use my own fork of DSPy because I had to implement asynchronous batching: https://github.com/rayanehmi/dspy/tree/feat/async_batching

# %%
from pathlib import Path
from typing import Literal
import os 

DATA_PATH = Path.cwd().parent / "data"
DATA_TYPE : Literal["train", "rank", "final"] = "train"
OUTPUT_DIR = os.path.join(DATA_PATH, "output_batches", DATA_TYPE)

# %%
# Load complete data
import polars as pl

SEGMENTS_PATH = os.path.join(OUTPUT_DIR, "complete.parquet")
df = pl.read_parquet(SEGMENTS_PATH)
df = df.cast({
    "alt_start": int,
    "alt_end": int,
    "peak_flight_altitude": int,
    "vertical_delta_up": int,
    "vertical_delta_down": int,
    "ground_speed_start": int,
    "ground_speed_end": int
})
# df.head()

# %%
df_masked = df.drop(("fuel_burnt"))
df_masked.head()
# Out:
# shape: (5, 12)
# ┌──────┬────────────┬──────────┬────────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ idx  ┆ flight_id  ┆ aircraft ┆ duration_m ┆ … ┆ vertical_d ┆ vertical_d ┆ ground_spe ┆ ground_sp │
# │ ---  ┆ ---        ┆ ---      ┆ in         ┆   ┆ elta_up    ┆ elta_down  ┆ ed_start   ┆ eed_end   │
# │ i64  ┆ str        ┆ str      ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │      ┆            ┆          ┆ str        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ i64       │
# ╞══════╪════════════╪══════════╪════════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 1143 ┆ prc7709629 ┆ A332     ┆ 12.0min    ┆ … ┆ 0          ┆ 25         ┆ 496        ┆ 496       │
# │      ┆ 46         ┆          ┆            ┆   ┆            ┆            ┆            ┆           │
# │ 1144 ┆ prc7709629 ┆ A332     ┆ 12.0min    ┆ … ┆ 25         ┆ 0          ┆ 496        ┆ 496       │
# │      ┆ 46         ┆          ┆            ┆   ┆            ┆            ┆            ┆           │
# │ 1145 ┆ prc7709629 ┆ A332     ┆ 12.0min    ┆ … ┆ 0          ┆ 25         ┆ 496        ┆ 496       │
# │      ┆ 46         ┆          ┆            ┆   ┆            ┆            ┆            ┆           │
# │ 1146 ┆ prc7709629 ┆ A332     ┆ 12.0min    ┆ … ┆ 25         ┆ 0          ┆ 496        ┆ 496       │
# │      ┆ 46         ┆          ┆            ┆   ┆            ┆            ┆            ┆           │
# │ 2474 ┆ prc7711277 ┆ B788     ┆ 25.0min    ┆ … ┆ 0          ┆ 25         ┆ 495        ┆ 538       │
# │      ┆ 08         ┆          ┆            ┆   ┆            ┆            ┆            ┆           │
# └──────┴────────────┴──────────┴────────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
import dspy
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")
gpt_4_1_nano = dspy.LM("openai/gpt-4.1-nano", api_key=api_key)
groq_api_key = os.getenv("GROQ_API_KEY")
gpt_oss_120b = dspy.LM("groq/openai/gpt-oss-120b", api_key=groq_api_key, cache=False)
gpt_5_1_instant = dspy.LM("openai/gpt-5.1", api_key=api_key, temperature=1.0, max_tokens=32000, reasoning_effort="none", cache=False)

json_adapter = dspy.JSONAdapter()

dspy.configure(lm=gpt_oss_120b, adapter=json_adapter)

# %%
from typing import Any, Annotated
import pydantic


class BurntFuelPrediction(dspy.Signature):
    """Predict the amount of fuel burnt in kgs by the plane over the given segment of flight.
    Segment data is constructed from noisy telemetry: use your common sense if values seem wrong.
    """
    aircraft: str = dspy.InputField()
    duration_min: str = dspy.InputField()
    route_icao: str = dspy.InputField()
    alt_start: int = dspy.InputField(desc="Altitude at the start of the segment in feet.")
    alt_end: int = dspy.InputField()
    peak_flight_altitude: int = dspy.InputField(desc="Peak altitude of the flight. Can be used to estimate the phase of the segment.")
    vertical_delta_up:  int = dspy.InputField(desc="Cumulative climb within the segment (summing positive altitude diffs).")
    vertical_delta_down: int = dspy.InputField()
    ground_speed_start: int = dspy.InputField(desc="Ground speed at the start of the segment.")
    ground_speed_end: int = dspy.InputField()
    fuel_burnt: int = dspy.OutputField(desc="Estimated amount of fuel burnt in kilograms.")  #  Can be an expression that will be evaluated (like '801 * 60 / 3.6')


# Zero-shot chain of thought
fuel_cot = dspy.ChainOfThought(BurntFuelPrediction)

# %%
eval_set = df[:25]
eval_set.head()
# Out:
# shape: (5, 13)
# ┌──────┬────────────┬────────────┬──────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ idx  ┆ fuel_burnt ┆ flight_id  ┆ aircraft ┆ … ┆ vertical_d ┆ vertical_d ┆ ground_spe ┆ ground_sp │
# │ ---  ┆ ---        ┆ ---        ┆ ---      ┆   ┆ elta_up    ┆ elta_down  ┆ ed_start   ┆ eed_end   │
# │ i64  ┆ f64        ┆ str        ┆ str      ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │      ┆            ┆            ┆          ┆   ┆ i64        ┆ i64        ┆ i64        ┆ i64       │
# ╞══════╪════════════╪════════════╪══════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 1143 ┆ 1106.76448 ┆ prc7709629 ┆ A332     ┆ … ┆ 0          ┆ 25         ┆ 496        ┆ 496       │
# │      ┆            ┆ 46         ┆          ┆   ┆            ┆            ┆            ┆           │
# │ 1144 ┆ 1070.47712 ┆ prc7709629 ┆ A332     ┆ … ┆ 25         ┆ 0          ┆ 496        ┆ 496       │
# │      ┆            ┆ 46         ┆          ┆   ┆            ┆            ┆            ┆           │
# │ 1145 ┆ 925.32768  ┆ prc7709629 ┆ A332     ┆ … ┆ 0          ┆ 25         ┆ 496        ┆ 496       │
# │      ┆            ┆ 46         ┆          ┆   ┆            ┆            ┆            ┆           │
# │ 1146 ┆ 943.47136  ┆ prc7709629 ┆ A332     ┆ … ┆ 25         ┆ 0          ┆ 496        ┆ 496       │
# │      ┆            ┆ 46         ┆          ┆   ┆            ┆            ┆            ┆           │
# │ 2474 ┆ 2000.0     ┆ prc7711277 ┆ B788     ┆ … ┆ 0          ┆ 25         ┆ 495        ┆ 538       │
# │      ┆            ┆ 08         ┆          ┆   ┆            ┆            ┆            ┆           │
# └──────┴────────────┴────────────┴──────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
def df_to_dspy_examples(row, with_fuel: bool = False):
    """Converts a row to a dspy.Example."""
    row_data = row.to_dicts()[0] if hasattr(row, "to_dicts") else row

    def clean(value):
        return "" if value is None else value

    inputs = [
        "aircraft",
        "duration_min",
        "route_icao",
        "alt_start",
        "alt_end",
        "peak_flight_altitude",
        # "vertical_delta_up",
        # "vertical_delta_down",
        # "ground_speed_start",
        # "ground_speed_end",
    ]
    payload = {key: clean(row_data.get(key)) for key in inputs}
    example = dspy.Example(**payload).with_inputs(*inputs)
    if with_fuel:
        example.fuel_burnt = clean(row_data.get("fuel_burnt"))
    return example

# %%
examples = [
    df_to_dspy_examples(row, with_fuel=True)
    for row in df.iter_rows(named=True)
]
examples[0]
# Out:
# Example({'aircraft': 'A332', 'duration_min': '12.0min', 'route_icao': 'ZSHC-NZAA', 'alt_start': 37025, 'alt_end': 37025, 'peak_flight_altitude': 37025, 'fuel_burnt': 1106.76448}) (input_keys={'alt_end', 'route_icao', 'alt_start', 'peak_flight_altitude', 'duration_min', 'aircraft'})

# %%
import random
import copy

randomized_examples = copy.deepcopy(examples)
random.Random(42).shuffle(randomized_examples)

# %% [markdown]
# ## Metrics

# %%
import math

def float_metric(gold: dspy.Example, pred: dspy.Prediction, trace=None):
    """Return a scalar score (negative squared error) for the evaluator."""
    true_value = gold.fuel_burnt
    pred_value = pred.fuel_burnt
    if true_value is None or pred_value is None:
        return float("nan")

    squared_error = (true_value - pred_value) ** 2

    if trace is None: # if we're doing evaluation or optimization
        return -squared_error
    else:  # During bootstrapping / trace collection we simply mark good demos.
        return squared_error < 40000  # Squared error 200.
    
fake_example = dspy.Example(features={"foo": "bar"}, fuel_burnt=500.0)
fake_prediction = dspy.Prediction(features={"foo": "bar"}, fuel_burnt=600.0)
print(float_metric(fake_example, fake_prediction))  # error -100.0
print(float_metric(fake_example, fake_prediction, trace='foo'))  # True
# Out:
# -10000.0
# True

# %% [markdown]
# ## Evaluation

# %%
from dspy.evaluate import Evaluate

# %%
evaluator_50 = Evaluate(
    devset=randomized_examples[:50],
    num_threads=50, 
    display_progress=True, 
    display_table=True
)

# %%
with dspy.context(lm=gpt_5_1_instant):
    eval_results = evaluator_50(fuel_cot, metric=float_metric, num_threads=25)
# Out:
# Average Metric: -7212037.73 / 50 (-14424075.5%): 100%|██████████| 50/50 [00:07<00:00,  6.57it/s]
# 2025/11/29 18:16:16 INFO dspy.evaluate.evaluate: Average Metric: -7212037.727646933 / 50 (-14424075.5%)
#    aircraft duration_min route_icao  alt_start  alt_end  peak_flight_altitude  \
# 0      B38M       1.0min  RCTP-WMKK      36000    33975                 36000
# 1      A359       3.0min  ZSPD-LEMD      38025    38025                 38050
# 2      B738       4.0min  LTFJ-EGCC      36000    36000                 36000
# 3      A20N       4.0min  KMDW-MMGL      37975    38025                 38075
# 4      A20N       1.0min  SKBO-KMCO       4150     2200                  6075
# 5      A20N       5.0min  MMTJ-MMUN      37000    37000                 37025
# 6      B789      14.0min  EHAM-KPDX      40000    40025                 40025
# 7      A320       4.0min  MMGL-KCLT      37000    37000                 37025
# 8      A20N       5.0min  SKBO-KORD      38000    38000                 38075
# 9      A320       5.0min  KORD-MMGL      36025    36000                 36025
# 10     A21N       4.0min  ZSPD-VHHH      32100    30000                 32100
# 11     A359       9.0min  ZSPD-YSSY      35000    37000                 37000
# 12     A320       4.0min  MMMM-KFAT      38000    36300                 38025
# 13     A320       5.0min  KOAK-MMGL        800    14500                 14500
# 14     B788       5.0min  SKBO-LEMD      39000    39025                 39025
# 15     A359      10.0min  EGPH-OMDB      39025    39025                 39050
# 16     B788      25.0min  LEMD-SKBO      41000    41000                 41000
# 17     A20N       2.0min  SEGU-KJFK       2900     1125                  2900
# 18     A320       5.0min  KORD-MMGL      33025    32975                 33050
# 19     A320       3.0min  MSLP-KJFK      30675    21050                 30675
# 20     A20N       4.0min  MSLP-KEWR      37025    37000                 37050
# 21     A359       8.0min  YSSY-ZSPD      38025    38025                 38025
# 22     A20N       5.0min  KJFK-MSLP      35975    36025                 36025
# 23     A20N       5.0min  KJFK-SEGU      27150    32725                 32725
# 24     A320       4.0min  MMMY-KLAX      38025    38025                 38050
# 25     A20N       5.0min  MGGT-KIAD      31200    12325                 31200
# 26     A20N       4.0min  KMDW-MMZC      38000    38000                 38075
# 27     A20N       7.0min  KMCO-KBOS        400      400                 37050
# 28     A320       4.0min  KDFW-MMGL      22575    30275                 30275
# 29     B788      17.0min  SKBO-EGLL      41025    41000                 41025
# 30     B738       5.0min  EDDL-LTAJ      37000    37000                 37000
# 31     A320       4.0min  KMIA-SKCG      37000    37000                 37000
# 32     A320       4.0min  KDFW-MMMM      36000    35975                 36025
# 33     B788      20.0min  LEMD-SKBO      40000    40025                 40025
# 34     A359      10.0min  EGPH-OMDB      41000    41000                 41025
# 35     A20N       5.0min  KIAD-MSLP      38050    38050                 38050
# 36     A20N       5.0min  MSLP-KSFO      38050    38050                 38050
# 37     A20N       4.0min  KORD-MMLO      32025    32025                 32050
# 38     B738       4.0min  LTFJ-EGSS      36000    36000                 36000
# 39     A359      15.0min  KLAX-NZAA      40000    40000                 40000
# 40     B77W      12.0min  EGKK-ZSPD      35025    35000                 35025
# 41     A320       4.0min  KSJC-MMGL      24600    30425                 30425
# 42     A20N      29.0min  KIAD-MSLP      32025    32075                 32075
# 43     B788       5.0min  SKBO-EGLL      40000    40000                 40000
# 44     A20N       5.0min  MMAS-KLAX      12925     8650                 12925
# 45     B77W      29.0min  EHAM-SBGR      34025    34025                 36025
# 46     A320       5.0min  KORD-MMGL      34025    34050                 34050
# 47     A320       5.0min  KSJC-MMZC      35525    37025                 37025
# 48     A20N       4.0min  KDFW-MMSP      30000    30025                 30025
# 49     A332       4.0min  EDDP-VIDP      39025    39025                 39050
#
#    vertical_delta_up vertical_delta_down  ground_speed_start  \
# 0               3900                5950                 473
# 1                 75                  75                 420
# 2                  0                   0                 389
# 3                425                 375                 456
# 4               6450                8375                 239
# 5                150                 175                 496
# 6               2950                2925                 465
# 7                675                 675                 441
# 8                950                 950                 455
# 9                400                 425                 356
# 10                75                2150                 417
# 11              2025                   0                 485
# 12                75                1750                 401
# 13             13775                  50                 173
# 14                25                   0                 457
# 15               525                 525                 503
# 16                25                   0                 474
# 17               125                1900                 209
# 18              1100                1150                 458
# 19                50                9675                 421
# 20               300                 325                 445
# 21                 0                   0                 430
# 22               800                 750                 492
# 23              5750                 150                 388
# 24               475                 475                 380
# 25                75               18950                 478
# 26               825                 825                 399
# 27                                                       102
# 28              7750                  25                 408
# 29                 0                  25                 504
# 30                 0                   0                 440
# 31                 0                   0                 438
# 32               900                 925                 447
# 33                25                   0                 426
# 34                50                  50                 505
# 35               875                 875                 464
# 36               850                 850                 441
# 37               100                 100                 407
# 38                 0                   0                 429
# 39                 0                   0                 422
# 40                 0                  25                 492
# 41             28475               22650                 439
# 42              5025                4975                 439
# 43                 0                  25                 486
# 44                25                4275                 346
# 45                 0                   0                 512
# 46               700                 675                 400
# 47              1675                 150                 476
# 48               700                 675                 458
# 49                75                  75                 472
#
#     ground_speed_end  example_fuel_burnt  \
# 0                462          200.000000
# 1                410          355.616128
# 2                400          217.724160
# 3                460           45.359200
# 4                204           41.276872
# 5                506           90.718400
# 6                461         1100.000000
# 7                442          100.000000
# 8                455          163.000000
# 9                354          200.000000
# 10               435          163.293120
# 11               485          969.779696
# 12               391          100.000000
# 13               373          500.000000
# 14               457          600.000000
# 15               513         1000.000000
# 16               441         1800.000000
# 17               154           41.276872
# 18               446          200.000000
# 19               380           18.000000
# 20               443          100.000000
# 21               430          752.055536
# 22               488           90.718400
# 23               395          123.377024
# 24               384          200.000000
# 25               381           72.000000
# 26               400          100.000000
# 27               102          362.873600
# 28               454          400.000000
# 29               504         1200.000000
# 30               446          127.005760
# 31               438          218.000000
# 32               443          200.000000
# 33               426          816.465600
# 34               509          800.000000
# 35               467           90.718400
# 36               435          163.000000
# 37               409           90.718400
# 38               428          254.011520
# 39               422         1496.853600
# 40               492         2866.000000
# 41               474          500.000000
# 42               461          544.310400
# 43               486          400.000000
# 44               279          100.000000
# 45               512         4200.000000
# 46               406          200.000000
# 47               487          300.000000
# 48               462           90.718400
# 49               471          400.000000
#
#                                                                 reasoning  \
# 0   Aircraft B38M (737 MAX 8). Segment is 1 minute long at high cruise...
# 1   Aircraft is an Airbus A350-900 (A359). Altitude is essentially con...
# 2   Aircraft: Boeing 737-800 at cruise (FL360 to FL360, no vertical ch...
# 3   Aircraft A20N (A320neo). Segment duration 4 minutes at about FL380...
# 4   Aircraft A20N (A320neo). Segment duration is 1 minute, altitude dr...
# 5   Aircraft A20N (A320neo) at essentially constant cruise altitude FL...
# 6   Aircraft: Boeing 787-9 (B789). Segment duration: 14 minutes (~0.23...
# 7   Segment is 4 minutes at essentially constant cruise altitude (37,0...
# 8   Aircraft A20N (A320neo). Segment is 5 minutes at essentially const...
# 9   Segment is at essentially peak cruise altitude (~FL360) with very ...
# 10  Segment is near cruise/top of descent for an A321neo (A21N), at FL...
# 11  Aircraft is an Airbus A350-900 (A359). Segment is 9 minutes, from ...
# 12  Segment is near cruise altitude (FL380 down to ~FL363) with small ...
# 13  Segment duration is 5 minutes in an A320, going from 800 ft to 14,...
# 14  Aircraft is a Boeing 787-8 (B788). Segment duration is 5 minutes a...
# 15  Aircraft A359 (A350-900), cruise segment near peak altitude FL390 ...
# 16  Aircraft is a Boeing 787-8 (B788). Segment is 25 minutes at consta...
# 17  Aircraft A20N (A320neo). Segment duration 2 minutes, low altitude ...
# 18  Segment is near cruise: altitude ~FL330 with very small net change...
# 19  Segment duration is 3 minutes for an A320 at high altitude, mostly...
# 20  Aircraft A20N (A320neo), cruise segment near FL370, essentially le...
# 21  Aircraft A359 (A350-900), cruise segment at FL380 with no altitude...
# 22  Aircraft A20N (A320neo). Segment is 5 minutes at/near cruise altit...
# 23  Aircraft A20N (A320neo). Segment duration 5 minutes. Altitude incr...
# 24  Segment is 4 minutes at essentially constant cruise altitude aroun...
# 25  Aircraft A20N (A320neo). Segment duration 5 minutes, from FL312 to...
# 26  Aircraft A20N (A320neo). Segment duration 4 minutes at essentially...
# 27  Aircraft is an Airbus A320neo (A20N). Segment duration is 7 minute...
# 28  Segment duration is 4 minutes in an A320, climbing from FL226 to F...
# 29  Aircraft B788 (787-8) at ~FL410, essentially level (tiny 25 ft des...
# 30  Segment is 5 minutes long at constant cruise altitude FL370 with e...
# 31  Segment is 4 minutes at constant cruise FL370 in an A320, with no ...
# 32  Segment is 4 minutes long at near-constant cruise altitude (around...
# 33  Segment is cruise at peak altitude (FL400) with negligible level c...
# 34  Aircraft A359 (A350-900), 10-minute segment at FL410 with negligib...
# 35  Aircraft A20N (A320neo). Segment duration 5 minutes at FL380, star...
# 36  Aircraft A20N (A320neo) at constant cruise altitude FL380, short 5...
# 37  Aircraft A20N (A320neo), level segment at ~FL320, 4 minutes durati...
# 38  Segment is 4 minutes at cruise for a B738 at FL360, essentially le...
# 39  Segment is cruise at constant altitude and speed for an A350-900 (...
# 40  Segment is short (12 minutes) at peak cruise altitude (~FL350) wit...
# 41  Segment duration is 4 minutes in an A320, climbing from FL246 to a...
# 42  Aircraft A20N (A320neo). Segment duration ~29 minutes at ~FL320, w...
# 43  Segment duration is 5 minutes at constant cruise altitude (FL400) ...
# 44  Aircraft A20N (A320neo). Segment is 5 minutes, mainly descent: sta...
# 45  Segment is 29 minutes long at essentially constant cruise altitude...
# 46  Segment is 5 minutes long at roughly constant cruise altitude near...
# 47  Segment duration is 5 minutes in an A320 at high altitude, essenti...
# 48  Aircraft A20N (A320neo). Segment is 4 minutes at about FL300, with...
# 49  Aircraft A332 (A330-200), cruise segment near peak altitude FL390 ...
#
#     pred_fuel_burnt       float_metric
# 0                43    ✔️ [-24649.000]
# 1               280     ✔️ [-5717.799]
# 2               170     ✔️ [-2277.595]
# 3               150    ✔️ [-10949.697]
# 4                24      ✔️ [-298.490]
# 5               200    ✔️ [-11942.468]
# 6              1400    ✔️ [-90000.000]
# 7               170     ✔️ [-4900.000]
# 8               200     ✔️ [-1369.000]
# 9               225      ✔️ [-625.000]
# 10              150      ✔️ [-176.707]
# 11              850    ✔️ [-14347.176]
# 12              160     ✔️ [-3600.000]
# 13              190    ✔️ [-96100.000]
# 14              210   ✔️ [-152100.000]
# 15              900    ✔️ [-10000.000]
# 16             1000   ✔️ [-640000.000]
# 17              100     ✔️ [-3448.406]
# 18              200        ✔️ [-0.000]
# 19               70     ✔️ [-2704.000]
# 20              170     ✔️ [-4900.000]
# 21              750        ✔️ [-4.225]
# 22              200    ✔️ [-11942.468]
# 23              225    ✔️ [-10327.229]
# 24              160     ✔️ [-1600.000]
# 25              100      ✔️ [-784.000]
# 26              150     ✔️ [-2500.000]
# 27              100    ✔️ [-69102.530]
# 28              200    ✔️ [-40000.000]
# 29             1500    ✔️ [-90000.000]
# 30              210     ✔️ [-6888.044]
# 31              170     ✔️ [-2304.000]
# 32              170      ✔️ [-900.000]
# 33             1750   ✔️ [-871486.476]
# 34              900    ✔️ [-10000.000]
# 35              200    ✔️ [-11942.468]
# 36              190      ✔️ [-729.000]
# 37              170     ✔️ [-6285.572]
# 38              160     ✔️ [-8838.166]
# 39             1300    ✔️ [-38751.340]
# 40             1200  ✔️ [-2775556.000]
# 41              170   ✔️ [-108900.000]
# 42             1100   ✔️ [-308790.932]
# 43              200    ✔️ [-40000.000]
# 44              210    ✔️ [-12100.000]
# 45             2900  ✔️ [-1690000.000]
# 46              210      ✔️ [-100.000]
# 47              220     ✔️ [-6400.000]
# 48              160     ✔️ [-4799.940]
# 49              370      ✔️ [-900.000]

# %%
def compute_rmse(eval_results):
    rmse = math.sqrt(abs(eval_results.score)/len(eval_results.results))
    return rmse

# %%
compute_rmse(eval_results)
# Out:
# 537.1047469535156

# %%
# dump in a csv file
import pandas as pd
import csv

results_list = []
for result in eval_results.results:
    true_value = result[0].fuel_burnt
    reasoning = result[1].reasoning
    pred_value = result[1].fuel_burnt
    metric = result[2]
    results_list.append({
        "true_value": true_value,
        "reasoning": reasoning,
        "pred_value": pred_value,
        "metric": metric
    })
results_df = pd.DataFrame(results_list)
results_df.to_csv("eval_results.csv", index=False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ## Usage

# %%
for lm in [gpt_5_1_instant]:
  cost = sum([x['cost'] for x in lm.history if x['cost'] is not None])
  print(cost)
# Out:
# 0.134725
