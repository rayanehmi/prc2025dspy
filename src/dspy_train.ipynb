# %% [markdown]
# ## DSPy train/eval
#
# Note: I use my own fork of DSPy because I had to implement asynchronous batching: https://github.com/rayanehmi/dspy/tree/feat/async_batching

# %%
from pathlib import Path
from typing import Literal
import os 

DATA_PATH = Path.cwd().parent / "data"
DATA_TYPE : Literal["train", "rank", "final"] = "final"
OUTPUT_DIR = os.path.join(DATA_PATH, DATA_TYPE)

# %%
# Load complete data
import polars as pl

SEGMENTS_PATH = os.path.join(OUTPUT_DIR, "llm_segments_" + DATA_TYPE + ".parquet")
print(SEGMENTS_PATH)
df = pl.read_parquet(SEGMENTS_PATH)
df.head()
# Out:
# c:\Users\rayte\Work\prc2025dspy\data\final\llm_segments_final.parquet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 SEGMENTS_PATH = os.path.join(OUTPUT_DIR, "llm_segments_" + DATA_TYPE + ".parquet")
#       5 print(SEGMENTS_PATH)
# ----> 6 df = pl.read_parquet(SEGMENTS_PATH)
#       7 df.head()
#
# File c:\Users\rayte\Work\prc2025dspy\.venv\Lib\site-packages\polars\_utils\deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File c:\Users\rayte\Work\prc2025dspy\.venv\Lib\site-packages\polars\_utils\deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File c:\Users\rayte\Work\prc2025dspy\.venv\Lib\site-packages\polars\io\parquet\functions.py:289, in read_parquet(source, columns, n_rows, row_index_name, row_index_offset, parallel, use_statistics, hive_partitioning, glob, schema, hive_schema, try_parse_hive_dates, rechunk, low_memory, storage_options, credential_provider, retries, use_pyarrow, pyarrow_options, memory_map, include_file_paths, missing_columns, allow_missing_columns)
#     286     else:
#     287         lf = lf.select(columns)
# --> 289 return lf.collect()
#
# File c:\Users\rayte\Work\prc2025dspy\.venv\Lib\site-packages\polars\_utils\deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File c:\Users\rayte\Work\prc2025dspy\.venv\Lib\site-packages\polars\lazyframe\opt_flags.py:328, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     327 kwargs["optimizations"] = optflags
# --> 328 return function(*args, **kwargs)
#
# File c:\Users\rayte\Work\prc2025dspy\.venv\Lib\site-packages\polars\lazyframe\frame.py:2422, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2420 # Only for testing purposes
#    2421 callback = _kwargs.get("post_opt_callback", callback)
# -> 2422 return wrap_df(ldf.collect(engine, callback))
#
# FileNotFoundError: Le chemin d’accès spécifié est introuvable. (os error 3): c:\Users\rayte\Work\prc2025dspy\data\final\llm_segments_final.parquet
#
# This error occurred with the following context stack:
# 	[1] 'parquet scan'
# 	[2] 'sink'

# %%
import dspy
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")
gpt_4_1 = dspy.LM("openai/gpt-4.1", api_key=api_key)
gpt_4_1_nano = dspy.LM("openai/gpt-4.1-nano", api_key=api_key)
groq_api_key = os.getenv("GROQ_API_KEY")
gpt_oss_120b = dspy.LM("groq/openai/gpt-oss-120b", api_key=groq_api_key, cache=False)
gpt_5_1_instant = dspy.LM("openai/gpt-5.1", api_key=api_key, temperature=1.0, max_tokens=32000, reasoning_effort="none", cache=False)

json_adapter = dspy.JSONAdapter()

dspy.configure(lm=gpt_4_1, adapter=json_adapter)

# %%
from typing import Any

class BurntFuelPrediction(dspy.Signature):
    """Predict the amount of fuel burnt in kgs by the plane over the given segment of flight.
    Segment data is constructed from noisy telemetry: use your common sense if values seem wrong.
    hint: vertical_rate_balance contains positive_frac, negative_frac and near_zero_frac, each corresponding 
    to the share of samples where vertical rate is respectively more than, less than or around 64 ft/min.
    hint 2: estimate the fuel weight penalty (heavy in the beginning, lighter in the end).
    """
    features : dict[str, Any] = dspy.InputField()
    fuel_kg : float = dspy.OutputField() 

# Zero-shot chain of thought
fuel_cot = dspy.ChainOfThought(BurntFuelPrediction)

# %%
def df_to_dspy_examples(row, with_fuel: bool = True):
    """Converts a row to a dspy.Example."""
    row_data = row.to_dicts()[0] if hasattr(row, "to_dicts") else row

    def clean(value):
        return "" if value is None else value

    inputs = [
        "aircraft_type",
        "origin_name",
        "origin_destination",
        "track_points_compact",
        "track_points_compact",
        "vertical_rate_balance"
    ]
    
    features = {key: clean(row_data.get(key)) for key in inputs}
    example = dspy.Example(features=features).with_inputs("features")
    if with_fuel:
        example.fuel_kg = clean(row_data.get("fuel_kg"))
    return example

# %%
examples = [
    df_to_dspy_examples(row, with_fuel=False)
    for row in df.iter_rows(named=True)
]
examples[0]
# Out:
# Example({'features': {'aircraft_type': 'B789', 'origin_name': 'Kuala Lumpur International Airport', 'origin_destination': '', 'track_points_compact': 'time 2025-04-13T02:31:04.447000->2025-04-13T03:01:04.487000 (30 min) | sources acars:2, adsb:3076 | altitude 3.597e+04 -> 3.597e+04 -> 3.6e+04 -> 3.6e+04 (delta 24.99, range 24.99, mean 3.599e+04) | groundspeed 467 -> 474 -> 471 -> 476 (delta 9, range 15, mean 472) | vertical_rate 0 -> 0 -> 0 -> -64 (delta -64, range 128, mean -3.36) | mach 0.86 -> 0.86 (delta 0, range 0, mean 0.86) | path 45.18/24.35 -> 45.9/22.72 -> 46.62/20.97 -> 47.22/19.52 | delta_lat 2.033 delta_lon -4.833 | phase cruise | vr balance +0.00 / -0.00 / ~0 1.00', 'vertical_rate_balance': {'positive_frac': 0.0, 'negative_frac': 0.0, 'near_zero_frac': 1.0}}}) (input_keys={'features'})

# %%
(0.59 + 0.84) / 1100 * len(examples)
# Out:
# 170.989

# %%
import random
import copy

randomized_examples = copy.deepcopy(examples)
random.Random(42).shuffle(randomized_examples)

# %% [markdown]
# ## Metrics

# %%
import math

def float_metric(gold: dspy.Example, pred: dspy.Prediction, trace=None):
    """Return a scalar score (negative squared error) for the evaluator."""
    true_value = gold.fuel_kg
    pred_value = pred.fuel_kg
    if true_value is None or pred_value is None:
        return float("nan")

    squared_error = (true_value - pred_value) ** 2

    if trace is None: # if we're doing evaluation or optimization
        return -squared_error
    else:  # During bootstrapping / trace collection we simply mark good demos.
        return squared_error < 40000  # Squared error 200.
    
fake_example = dspy.Example(features={"foo": "bar"}, fuel_kg=500.0)
fake_prediction = dspy.Prediction(features={"foo": "bar"}, fuel_kg=600.0)
print(float_metric(fake_example, fake_prediction))  # error -100.0
print(float_metric(fake_example, fake_prediction, trace='foo'))  # True
# Out:
# -10000.0
# True

# %% [markdown]
# ## Evaluation

# %%
from dspy.evaluate import Evaluate

# %%
evaluator_50 = Evaluate(
    devset=randomized_examples[:50],
    num_threads=50, 
    display_progress=True, 
    display_table=True
)

evaluator_500 = Evaluate(
    devset=randomized_examples[:400],
    num_threads=15, 
    display_progress=True, 
    display_table=True
)

# %%
with dspy.context(lm=gpt_oss_120b):
    eval_results = evaluator_500(fuel_cot, metric=float_metric)

# %%
def compute_rmse(eval_results):
    rmse = math.sqrt(abs(eval_results.score)/len(eval_results.results))
    return rmse

# %%
compute_rmse(eval_results)

# %%
# dump in a csv file
import pandas as pd
import csv

results_list = []
for result in eval_results.results:
    true_value = result[0].fuel_burnt
    reasoning = result[1].reasoning
    pred_value = result[1].fuel_burnt
    metric = result[2]
    results_list.append({
        "true_value": true_value,
        "reasoning": reasoning,
        "pred_value": pred_value,
        "metric": metric
    })
results_df = pd.DataFrame(results_list)
results_df.to_csv("eval_results.csv", index=False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ## Batch API

# %%
from tqdm import tqdm

EXAMPLES_PER_BATCH = 100

list_of_batches = []
# 0. prepare batches of 100 examples each
for i in tqdm(
    range(0, len(examples), EXAMPLES_PER_BATCH)
):
    batch_range = examples[i : i + EXAMPLES_PER_BATCH]
    list_of_batches.append(batch_range)
# Out:
# 100%|██████████| 1316/1316 [00:00<00:00, 997056.37it/s]

# %%
list_of_batches[0][0]
# Out:
# Example({'features': {'aircraft_type': 'B789', 'origin_name': 'Kuala Lumpur International Airport', 'origin_destination': '', 'track_points_compact': 'time 2025-04-13T02:31:04.447000->2025-04-13T03:01:04.487000 (30 min) | sources acars:2, adsb:3076 | altitude 3.597e+04 -> 3.597e+04 -> 3.6e+04 -> 3.6e+04 (delta 24.99, range 24.99, mean 3.599e+04) | groundspeed 467 -> 474 -> 471 -> 476 (delta 9, range 15, mean 472) | vertical_rate 0 -> 0 -> 0 -> -64 (delta -64, range 128, mean -3.36) | mach 0.86 -> 0.86 (delta 0, range 0, mean 0.86) | path 45.18/24.35 -> 45.9/22.72 -> 46.62/20.97 -> 47.22/19.52 | delta_lat 2.033 delta_lon -4.833 | phase cruise | vr balance +0.00 / -0.00 / ~0 1.00', 'vertical_rate_balance': {'positive_frac': 0.0, 'negative_frac': 0.0, 'near_zero_frac': 1.0}}}) (input_keys={'features'})

# %%
import os

list_of_artifacts = []
for (i, minibatch) in tqdm(enumerate(list_of_batches), total=len(list_of_artifacts)):
    # 1. create a jsonl file
    artifacts = fuel_cot.create_batch_file(
        minibatch,
        input_file_path=os.path.join(OUTPUT_DIR, "batches", str(i)+".jsonl"),
        # endpoint="/v1/chat/completions"
    )
    list_of_artifacts.append(artifacts)
# Out:
# 195it [00:03, 60.42it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 6
#       3 list_of_artifacts = []
#       4 for (i, minibatch) in tqdm(enumerate(list_of_batches), total=len(list_of_artifacts)):
#       5     # 1. create a jsonl file
# ----> 6     artifacts = fuel_cot.create_batch_file(
#       7         minibatch,
#       8         input_file_path=os.path.join(OUTPUT_DIR, "batches", str(i)+".jsonl"),
#       9         # endpoint="/v1/chat/completions"
#      10     )
#      11     list_of_artifacts.append(artifacts)
#
# File c:\Users\rayte\Work\prc2025dspy\.venv\Lib\site-packages\dspy\primitives\module.py:224, in Module.create_batch_file(self, examples, endpoint, input_file_path, custom_id_prefix)
#     216 normalized_examples = _normalize_examples(examples)
#     217 writer = _BatchRequestWriter(
#     218     module=self,
#     219     predictor=predictor,
#    (...)    222     custom_id_prefix=custom_id_prefix,
#     223 )
# --> 224 request_file, metadata_path, metadata = writer.write(normalized_examples, input_file_path)
#     226 if writer.provider_name is None or writer.endpoint is None or writer.model_name is None:
#     227     raise RuntimeError("Unable to infer LM provider/model information for batch creation.")
#
# File c:\Users\rayte\Work\prc2025dspy\.venv\Lib\site-packages\dspy\primitives\module.py:571, in _BatchRequestWriter.write(self, examples, requested_path)
#     569 for idx, example_inputs in enumerate(examples):
#     570     request_line = self._build_request_line(example_inputs, idx)
# --> 571     buffer.write(json.dumps(request_line, ensure_ascii=False))
#     572     buffer.write("\n")
#     573     metadata_entries.append(
#     574         {
#     575             "custom_id": request_line["custom_id"],
#    (...)    578         }
#     579     )
#
# KeyboardInterrupt:

# %%
artifact = list_of_artifacts[0]
artifact
# Out:
# BatchRequestArtifacts(request_file=WindowsPath('c:/Users/rayte/Work/prc2025dspy/data/train/batches/0.jsonl'), metadata_file=WindowsPath('c:/Users/rayte/Work/prc2025dspy/data/train/batches/0.jsonl.metadata.json'), metadata={'generated_at': '2025-11-29T21:53:08.615742Z', 'request_file': 'c:\\Users\\rayte\\Work\\prc2025dspy\\data\\train\\batches\\0.jsonl', 'endpoint': 'openai/v1/batches', 'dependency_versions': {'python': '3.13', 'dspy': '3.1.0b1', 'cloudpickle': '3.1'}, 'module': {'class_path': 'dspy.predict.chain_of_thought.ChainOfThought', 'repr': 'predict = Predict(StringSignature(features -> reasoning, fuel_kg\n    instructions=\'Predict the amount of fuel burnt in kgs by the plane over the given segment of flight.\\nSegment data is constructed from noisy telemetry: use your common sense if values seem wrong.\\nhint: vertical_rate_balance contains positive_frac, negative_frac and near_zero_frac, each corresponding \\nto the share of samples where vertical rate is respectively more than, less than or around 64 ft/min.\\nhint 2: estimate the fuel weight penalty (heavy in the beginning, lighter in the end).\'\n    features = Field(annotation=dict[str, Any] required=True json_schema_extra={\'__dspy_field_type\': \'input\', \'prefix\': \'Features:\', \'desc\': \'${features}\'})\n    reasoning = Field(annotation=str required=True json_schema_extra={\'prefix\': "Reasoning: Let\'s think step by step in order to", \'desc\': \'${reasoning}\', \'__dspy_field_type\': \'output\'})\n    fuel_kg = Field(annotation=float required=True json_schema_extra={\'__dspy_field_type\': \'output\', \'prefix\': \'Fuel Kg:\', \'desc\': \'${fuel_kg}\'})\n))'}, 'lm': {'model': 'openai/gpt-oss-120b', 'provider': 'groq', 'type': 'chat'}, 'examples': [{'custom_id': 'chainofthought-0-0144af6e', 'index': 0, 'inputs': {'features': {'aircraft_type': 'B789', 'origin_name': 'Kuala Lumpur International Airport', 'origin_destination': '', 'track_points_compact': 'time 2025-04-13T02:31:04.447000->2025-04-13T03:01:04.487000 (30 min) | sources acars:2, adsb:3076 | altitude 3.597e+04 -> 3.597e+04 -> 3.6e+04 -> 3.6e+04 (delta 24.99, range 24.99, mean 3.599e+04) | groundspeed 467 -> 474 -> 471 -> 476 (delta 9, range 15, mean 472) | vertical_rate 0 -> 0 -> 0 -> -64 (delta -64, range 128, mean -3.36) | mach 0.86 -> 0.86 (delta 0, range 0, mean 0.86) | path 45.18/24.35 -> 45.9/22.72 -> 46.62/20.97 -> 47.22/19.52 | delta_lat 2.033 delta_lon -4.833 | phase cruise | vr balance +0.00 / -0.00 / ~0 1.00', 'vertical_rate_balance': {'positive_frac': 0.0, 'negative_frac': 0.0, 'near_zero_frac': 1.0}}}}, {'custom_id': 'chainofthought-1-8e9561c5', 'index': 1, 'inputs': {'features': {'aircraft_type': 'B789', 'origin_name': 'Kuala Lumpur International Airport', 'origin_destination': '', 'track_points_compact': 'time 2025-04-13T03:01:04.487000->2025-04-13T03:16:04.226000 (15 min) | sources acars:2, adsb:1788 | altitude 3.6e+04 -> 3.597e+04 -> 3.6e+04 -> 3.597e+04 (delta -24.99, range 24.99, mean 3.599e+04) | groundspeed 476 -> 477 -> 489 -> 495 (delta 19, range 22, mean 484.7) | vertical_rate 0 -> 0 -> 0 -> 0 (delta 0, range 128, mean -29.86) | mach 0.86 -> 0.86 (delta 0, range 0, mean 0.86) | path 47.22/19.52 -> 47.56/18.66 -> 47.88/17.8 -> 48.23/16.95 | delta_lat 1.017 delta_lon -2.567 | phase cruise | vr balance +0.00 / -0.00 / ~0 1.00', 'vertical_rate_balance': {'positive_frac': 0.0, 'negative_frac': 0.0, 'near_zero_frac': 1.0}}}}, {'custom_id': 'chainofthought-2-f3bc632b', 'index': 2, 'inputs': {'features': {'aircraft_type': 'B789', 'origin_name': 'Kuala Lumpur International Airport', 'origin_destination': '', 'track_points_compact': 'time 2025-04-13T03:16:04.458000->2025-04-13T03:46:04.417000 (30 min) | sources acars:2, adsb:3478 | altitude 3.6e+04 -> 3.6e+04 -> 3.6e+04 -> 3.6e+04 (delta 0, range 24.99, mean 3.599e+04) | groundspeed 495 -> 514 -> 518 -> 515 (delta 20, range 32, mean 511.9) | vertical_rate 64 -> 0 -> 0 -> -64 (delta -128, range 192, mean -36.04) | mach 0.86 -> 0.86 ( ...

# %%
# 2. send it to the endpoint
# batch_handle = await fuel_cot.asubmit_batch_file(
#     artifact,
#     completion_window="24h",
# )

predictions = await fuel_cot.abatch(
    examples=list_of_batches[0]
)

# %%
predictions
# Out:
# [Prediction(
#      reasoning='This segment covers a 30-minute cruise phase in a Boeing 787-9 (B789), at a near-constant cruise altitude and speed (FL360, Mach 0.86, 472 knots mean). Vertical rate is essentially zero, indicating steady level flight. For a B789, typical cruise fuel burn ranges from about 5 to 6 metric tons per hour, depending on weight and engines, but this appears to be a mid-late cruise segment (fuel weight somewhat reduced, so better efficiency than in initial cruise climb). For 30 minutes, the fuel burn would therefore be (5 to 6)/2 = 2.5 to 3.0 metric tons (2500-3000 kg). Given steady cruise at optimal speed and altitude, use 2700 kg as a reasonable average.',
#      fuel_kg=2700.0
#  ),
#  Prediction(
#      reasoning="This is a mid-cruise segment for a Boeing 787-9 (B789), spanning 15 minutes at near-constant cruise altitude (~36,000 ft), stable mach (0.86), and no significant vertical movement (vertical_rate consistently ~0, with 'near_zero_frac' 1.0). Cruise phases are typically the most fuel-efficient per km but a B789 still burns a significant amount due to its size. Generic cruise burn for a B789 is around 5.2 metric tonnes/hour (approx 87 kg/min). For 15 minutes, fuel burn is therefore approximately 1,305 kg (5,220 kg/hr * 0.25 hr). There are no unusual aircraft weight considerations given the phase/detail, so no extra penalty applied.",
#      fuel_kg=1305.0
#  ),
#  Prediction(
#      reasoning="This is a 30-minute cruise segment at FL360 (36,000 ft) for a Boeing 787-9 (B789). Groundspeed averages 512 knots, so in 30 minutes, the plane travels ~256 nm. During cruise, fuel flow for a B789 is typically about 5,500 kg/h at high weights, and can decrease over time as the aircraft gets lighter. Given the very small vertical rate and the stable altitude, the aircraft is in level cruise, so no extra fuel for climb or descent. Therefore, for 0.5 hours, the estimated fuel burn is about 5,500 kg/h * 0.5 = 2,750 kg. Accounting for the aircraft likely still being on the heavier side (early in the flight) and possible extra drag or inefficiencies, I'll adjust this upwards slightly to around 3,000 kg.",
#      fuel_kg=3000.0
#  ),
#  Prediction(
#      reasoning='This segment is 15 minutes in duration for a B789 (Boeing 787-9) at cruise altitude (almost constant at ~35,990 ft) and speed (mean 506.4 knots, mach 0.86). The vertical rate is almost always near zero, confirming steady cruise (near_zero_frac=0.89). For cruise at this altitude and weight (likely still substantial given not far from origin), the B789 typically burns about 5,200-5,800 kg/h at cruise (depending on mass/conditions). For 15 minutes: use upper end due to early cruise and higher fuel weight: 5,800 kg/h ÷ 4 = 1,450 kg.',
#      fuel_kg=1450.0
#  ),
#  Prediction(
#      reasoning='This is a Boeing 787-9 (B789) in descent phase, departing from Kuala Lumpur. The segment is about 15 minutes long, and altitude drops significantly from 36,000 ft to 15,230 ft. The phase is dominated by descent (vertical rate balance: 73% negative, no climb), and mean groundspeed stays high (467 knots), indicating an active, fast descent, possibly at flight idle for much of it. Fuel burn during descent is considerably lower than during cruise due to reduced engine thrust. Typically, a B789 burns roughly 2,400–2,700 kg/hr at idle descent, so over 15 minutes, the expected burn is around 600–675 kg even considering deceleration (mach 0.86 down to 0.59) and a gradually lightening aircraft. The heavier starting weight is only mildly relevant for descent. Minor engine spooling may occur toward the end of descent as speed and altitude decrease, so I will estimate at the higher end of the idle descent envelope.',
#      fuel_kg=675.0
#  ),
#  Prediction(
#      reasoning='The segment is a level phase (constant altitude at 37,010 ft) on an Airbus A350-900 (A359), lasting about 28 minutes. At this phase, the plane is likely in cruise with high efficiency. Given that no significant altitude change occurred (no climb or descent), fuel burn should reflect steady cruise consumption. For the A359, typical cruise fuel burn is about 5,500-6,000 kg/hour at max weight, decreasing somewhat as weight drops, but over just a 28-minute segment the penalty will be minimal. Estimating using 5,700 kg/hour: (28.09/60) * 5,700 ≈ 2,671 kg.',
#      fuel_kg=2670.0
#  ),
#  Prediction(
#      reasoning="The segment is a level cruise phase at high altitude (37,010 ft) on an A350-900 (A359), lasting just over 4 minutes. During cruise at this altitude, typical fuel burn is around 2,000–2,500 kg/hr for this aircraft depending on mass and conditions. In 4 minutes (about 1/15th of an hour), this would equate to roughly 133–166 kg of fuel. Since there is no significant climb or descent (altitude is flat), the fuel burn will be steady and typical for cruise. Also, early in cruise, fuel weight is higher, so let's assume it is on the higher side of the cruise fuel burn range.",
#      fuel_kg=160.0
#  ),
#  Prediction(
#      reasoning='The segment covers a 20-minute period of level flight at approximately 37,000 ft with almost no altitude change. The aircraft is an A359 (Airbus A350-900), a widebody twinjet with typical cruise fuel burn rates of about 5,500–6,000 kg per hour at cruise altitude, but can be a bit higher at the start of a long flight (due to heavier fuel load). 20 minutes is 1/3 hour, so estimated fuel burned is around (5,500 to 6,200 kg) * 0.33, i.e., approximately 1,800 to 2,000 kg. Because the altitude is perfectly steady, this segment is likely mid-cruise, so I’ll use the lower end of cruise burn.',
#      fuel_kg=1850.0
#  ),
#  Prediction(
#      reasoning="The segment duration is about 16 minutes with the A359 cruising at a steady altitude of 37,000 ft (essentially zero altitude change) and identified as a 'level' flight phase (i.e., cruise), over a modest distance. For a modern, efficient widebody like the A359, typical cruise fuel consumption is roughly 5-6 metric tons per hour at max weight, but will be somewhat lower as fuel burns off and weight reduces, and slightly less for a ~16-minute segment due to lighter intermediate weight. For 16.16 minutes (~0.27 hours), estimating cruise burn between 1.3-1.6 tons (1300-1600 kg), with a small penalty for heavy initial weight offset by burn-off. Given these constraints, a conservative estimate would be around 1,400 kg of fuel burnt for this segment.",
#      fuel_kg=1400.0
#  ),
#  Prediction(
#      reasoning="The segment describes an A350-900 at stable cruise altitude (37,000 ft) for about 3.9 minutes, with negligible altitude change (delta 2 ft) and phase marked as 'level.' Cruise segments burn fuel at the most efficient rate for the aircraft, and since it is early in the flight (origin is Pudong, no destination), fuel load is likely heavy, increasing burn rate slightly. The A359 typically burns around 5.5-6 tonnes (5500-6000 kg) of fuel per hour during cruise at heavy weight. For a 3.9 min segment, that's (3.9/60) * 5800 ≈ 377 kg.",
#      fuel_kg=377.0
#  ),
#  Prediction(
#      reasoning='The aircraft is an Airbus A350-900 (A359), cruising at near-constant altitude (mean 37,010 ft, delta only 8 ft), confirming a steady cruise/level segment. The time duration is about 8 minutes. For a long-haul aircraft like the A359, fuel burn during cruise is usually around 5,500-6,000 kg/hr early in the flight (heavier weight) and about 5,000 kg/hr when lighter. Since this segment is short (8 minutes = 8/60 = 0.133 hours), the total burn is roughly between 665-800 kg based on average cruise consumption. Given little altitude change and assuming early-cruise weight penalty, I use a slightly higher average (6,000 kg/hr) for safety.',
#      fuel_kg=800.0
#  ),
#  Prediction(
#      reasoning='The segment is flown by an A359 (Airbus A350-900), a large twin-aisle aircraft. The segment lasts about 4 minutes, at a stable cruise altitude (around 37,000 ft), with minimal altitude change (delta -7 ft). This is cruise, with minimal climb/descent, no significant maneuvering. At this phase (early in the flight from Shanghai Pudong), the aircraft is likely heavy with fuel. Average cruise fuel burn for an A359 is about 5,500 kg/hr at initial weights, but can vary. 4 minutes is roughly 1/15th of an hour, so expected burn is 5500/15 ≈ 367 kg. Adjust a bit higher than pure average for heavy weight penalty early in cruise.',
#      fuel_kg=380.0
#  ),
#  Prediction(
#      reasoning="The aircraft is an Airbus A350-900 (A359), flying at a constant altitude of 37,000 ft for a short duration of about 4 minutes during the cruise (level) phase. For modern widebody jets like the A359, a typical cruise fuel flow is around 5,000-6,000 kg per hour. Over 4 minutes (~0.067 hours), fuel burn would be approximately 5,500 kg/hr x 0.067 hr = 368.5 kg. Considering the high cruise altitude and likely heavy initial weight (shortly after departure), I'll round up slightly to account for higher fuel flow at heavy weight.",
#      fuel_kg=380.0
#  ),
#  Prediction(
#      reasoning="The aircraft is an Airbus A350-900 (A359) flying at cruising altitude (around 37,010 ft, essentially constant altitude) for 12.04 minutes in the 'level' (cruise) phase. The fuel burn during cruise for an A359 is typically about 5,500 to 6,000 kg per hour under average loads and conditions. Since the segment is at constant altitude (efficient cruise, no climbing or descending), we should use the lower end. For 12.04 minutes out of 60 minutes (1 hour), that's (12.04/60) ≈ 0.2007 hours. Multiplying: 0.2007 h * 5,800 kg/h ≈ 1,164 kg. The segment is short and at stable cruise, no abnormal telemetry values, making this a typical cruise segment.",
#      fuel_kg=1164.0
#  ),
#  Prediction(
#      reasoning='The segment describes a climb phase of an Airbus A350-900 (A359), lasting approximately 48 minutes, where altitude increases from 37,010 ft to 39,010 ft, a gain of 1,994 ft. Climb phases, especially at high altitude, burn more fuel due to heavier aircraft weight and higher engine output required. The segment covers a relatively small altitude change, likely corresponding to a step climb during cruise. For a heavy long-haul aircraft like the A359, even a small altitude increase at cruise (especially during the initial, heavier stages of flight) can result in significant fuel burn. Based on typical step climb fuel use for this type (estimating climb fuel rate to be 3,000-4,000 kg/hr at these altitudes, slightly higher than cruise burn) and the time of 48.16 min, the approximate fuel burn would be in the range of 2,400 to 3,200 kg, leaning toward the higher end if the aircraft is still relatively heavy.',
#      fuel_kg=2800.0
#  ),
#  Prediction(
#      reasoning='The segment describes a cruise phase in an Airbus A350-900 (A359) over approximately 4 minutes. The altitude is essentially constant (mean 38,000 ft; delta 6 ft), and the vertical rate is near zero for 100% of the segment, confirming steady level flight. Groundspeed is stable (mean ~476.5 knots, range is narrow). In cruise, fuel burn is relatively flat and moderate versus climb or descent; for a heavy long-haul widebody like A359, typical cruise consumption is 5,400–6,000 kg/hr at the start of cruise, gradually decreasing as the aircraft lightens, but 4–5 min represents a marginal variation. For a 4 minute (0.067 hr) cruise at a likely burn rate of ~5,500 kg/hr, the fuel burn would be about 370 kg. Adjusting for a small sample and possible noise, a reasonable estimation is around 370 kg.',
#      fuel_kg=370.0
#  ),
#  Prediction(
#      reasoning='This is a short segment (about 4 minutes) in cruise phase at high altitude (around 38,000 ft) with almost zero vertical rate, indicating level flight. The groundspeed is stable (mean 469 kt), suggesting efficient cruise. For an A350-900 (A359), typical cruise fuel flow is around 5,600 kg/h, but at the end of a long trip (since the origin is Shanghai Pudong and the plane is already at cruise), fuel weight penalty is somewhat reduced. Estimate: (4.02/60) hours × 5600 kg/h ≈ 375 kg, with a slight decrement for end-of-cruise efficiency. Final estimate about 360 kg.',
#      fuel_kg=360.0
#  ),
#  Prediction(
#      reasoning="The segment is a short 4-minute cruise at a steady altitude (mean ~38,000 ft, delta 2 ft), with near-constant groundspeed (~454 knots) and no vertical excursions (vertical rate at or near zero for 100% of time). For an A359 (Airbus A350-900), typical cruise fuel flow is on the order of 5,500-6,000 kg/h (for both engines combined). Adjusting for fuel penalty at the segment's likely weight (early/later in flight unknown), even with some uncertainty, over 4 minutes the burn is (6000 kg/h)/60*4 ≈ 400 kg. Accounting for short segment, conservatively estimating at 380 kg.",
#      fuel_kg=380.0
#  ),
#  Prediction(
#      reasoning='Segment duration is just over 4 minutes, in cruise at FL380 (38,000 ft) with nearly constant altitude and speed (mean groundspeed 452.3 kt, negligible vertical rate). For a long-haul widebody like the A350-900, fuel burn is highest during climb and much lower during cruise, and further reduces over time as weight drops. At the beginning of cruise, with a heavy fuel weight, we can estimate cruise fuel flow at ~5,000-5,500 kg/h. For 4 minutes: (5,250 kg/h * 4/60) ≈ 350 kg. I’ll use 350 kg to reflect that this is the early cruise segment and the plane is still heavy.',
#      fuel_kg=350.0
#  ),
#  Prediction(
#      reasoning='The flight segment is 4.01 minutes long and entirely in cruise phase at approximately 38,000 ft. The aircraft type is an A350-900 (A359), a modern, fuel-efficient widebody typically burning around 5-6 tons (5000-6000 kg) per hour at cruise at high gross weight. The vertical rate remains near zero for the segment, and ground speed averages 451 knots, indicating steady cruise with minimal climbing or descending, which aligns with lower fuel burn than climb. For 4.01 minutes (= 0.0668 hours), assuming a cruise burn rate of roughly 5600 kg/hr (typical for a near-maximum gross weight intercontinental flight), the fuel used would be about: 5600 kg/hr * 0.0668 hr = 374 kg. The fuel burn penalty from a heavy initial segment is present, but as the phase is well into cruise, weight should have dropped somewhat. To account for some uncertainty and possible heavy loading, a slight upward adjustment is reasonable.',
#      fuel_kg=400.0
#  ),
#  Prediction(
#      reasoning="The segment is a cruise phase of an Airbus A350-900 (A359), lasting roughly 4 minutes at a constant altitude of about 38,000 ft, with groundspeed around 445 knots. The vertical rate is essentially zero throughout (100% in near-zero), so this is steady cruise. In long-haul jets like the A359, cruise fuel flow is typically about 5,000-6,000 kg/hr for both engines combined, depending on weight and conditions. As this is near the start of a long segment, let's estimate conservatively on the upper side (heavier aircraft). 4 minutes is 4/60 = 0.0667 hours. 6,000 kg/hr * 0.0667 = about 400 kg. Given the slight uncertainty and short time window, I'll round to a realistic cruise segment burn.",
#      fuel_kg=400.0
#  ),
#  Prediction(
#      reasoning='The segment lasts about 16 minutes (0.267 hours) at a steady cruise altitude (38,000 ft), with near constant groundspeed (mean 446.8 knots) and essentially no vertical movement. An Airbus A350-900 (A359) at cruise typically burns around 5,700-6,000 kg/hr at initial max weight, decreasing as the aircraft gets lighter. Given this is a cruise segment and the fuel burn decreases slightly over the cruise, an average fuel flow of 5,500 kg/hr is a reasonable mid-cruise estimate. For 0.267 hours: 0.267 × 5,500 ≈ 1,468.5 kg.',
#      fuel_kg=1468.5
#  ),
#  Prediction(
#      reasoning='The flight segment is for an Airbus A350-900 (A359) during cruise phase at a steady altitude (~38,000 ft) and near-constant speed (~441 knots) over approximately 4 minutes. The vertical rate is essentially zero (level cruise flight), so the engines are set to an efficient cruise thrust. For a modern widebody like the A359, typical cruise fuel flow per engine is about 2,300-2,500 kg/hour; with two engines, total is about 4,600-5,000 kg/hour. Over 4 minutes (4/60 = 0.0667 hours), the estimated fuel burn would be approximately 4,800 × 0.0667 ≈ 320 kg, considering the aircraft is still relatively heavy from initial cruise. Adding a modest buffer for potential variations, a reasonable estimate is about 325 kg.',
#      fuel_kg=325.0
#  ),
#  Prediction(
#      reasoning="This is a 4-minute segment during cruise at a stable altitude around 38,000 ft with near-zero vertical rate throughout, typical for cruise flight where fuel burn is determined mainly by weight (early cruise, so still relatively heavy), altitude, speed, and aircraft type. For an Airbus A350-900, cruise fuel flow is typically in the range of 5,800–6,000 kg/h (both engines combined) in early cruise when the aircraft is heavy. For a 4-minute window, that's 4/60 × 6000 ≈ 400 kg, but possibly slightly less since not absolute maximum GW and speed is normal. Thus, an estimate of approximately 390 kg seems reasonable for this segment.",
#      fuel_kg=390.0
#  ),
#  Prediction(
#      reasoning='The segment is a stable 44-minute cruise portion for an Airbus A350-900 (A359) at approximately 38,000 ft, with groundspeed stable around 434 knots and almost no vertical movement (100% vertical_rate near zero). During cruise, fuel burn is at its most efficient, but still significant due to the long duration. Typical A359 cruise fuel burns are around 5.5–6.5 metric tons per hour depending on weight, with early cruise often on the higher side. For 44.15 minutes (0.736 hours), and considering mid-cruise (not initial climb), assume average cruise burn ≈ 6,000 kg/hour. Multiplying: 0.736 × 6000 kg ≈ 4,416 kg. Adjust slightly downward given stability and likely weight reduction during cruise; a reasonable estimate is about 4,250 kg.',
#      fuel_kg=4250.0
#  ),
#  Prediction(
#      reasoning='This segment is a short (4-minute) portion of cruise flight at a constant high altitude (~38,000 ft) and nearly constant groundspeed (mean 438.3 knots). The vertical rate is near zero (flat cruise), indicating no significant climbs or descents. For an A350-900 in cruise at this weight, typical cruise fuel burn rates are around 2400-2700 kg/hr (sometimes slightly lower at optimal altitude and lighter weights). Since the segment is early in flight, the aircraft is likely heavier, so use the higher side of cruise rates. Fuel burn for 4 minutes (~1/15 of an hour) at ~2600 kg/hr = 2600/15 ≈ 173 kg.',
#      fuel_kg=173.0
#  ),
#  Prediction(
#      reasoning='The segment covers about 4 minutes of flight in cruise phase at a nearly constant high altitude (around 38,000 feet, minor fluctuation), as indicated by the vertical rate balance (1.00 near-zero fraction). The groundspeed is steadily increasing (436 to 453 knots, mean ~444 knots), implying typical cruise power setting. The aircraft is an A359 (Airbus A350-900), a modern widebody with efficient engines and high passenger capacity. Average hourly cruise fuel burn for the A350-900 is about 5300 to 6000 kg/hour at weight in mid-to-late cruise, and slightly higher at max weight, but in this short segment, the weight penalty change is minor. Over 4.018 minutes (4.018/60 ≈ 0.067 hours), estimated fuel burn is 5300 kg/h * 0.067 = 355 kg; using the higher end (e.g. if fully loaded) would be about 6000 kg/h * 0.067 = 402 kg. Since the segment is cruise and the telemetry is stable, using the mean value (380 kg) is a reasonable estimate.',
#      fuel_kg=380.0
#  ),
#  Prediction(
#      reasoning='The segment is a short cruise phase of 4 minutes for an Airbus A350-900 (A359), maintaining essentially constant altitude (~38,000 ft) and steady groundspeed (~453 kt). The vertical rate is near zero, indicating truly level flight with no climb or descent, so no extra fuel is required for altitude change. For cruise, fuel consumption is mainly a function of speed, weight (penalty highest at start), and duration. For a heavy long-haul airliner at cruise, an average hourly cruise fuel burn is roughly 5,500-6,500 kg/h at the beginning, potentially trending lower over time. 4 minutes is about 1/15th of an hour. Using 6,000 kg/h × (4/60) ≈ 400 kg. Since steady level flight may skew slightly lower, but initial cruise is still heavy, estimate between 350-450 kg. Choose a representative value.',
#      fuel_kg=400.0
#  ),
#  Prediction(
#      reasoning='This segment is a short cruise phase (about 4 minutes) at a high, steady altitude (38,000 ft) and stable groundspeed (~457 kt) on an A350-900. The vertical rate is essentially zero, indicating level cruise. Fuel consumption in cruise for an A359 is typically about 5,000-5,500 kg/hour at high weights, but this segment is only 4 minutes (1/15th of an hour), and toward the middle or end of cruise, the aircraft will have burned off some weight, making fuel flow slightly lower. Using a cruise consumption estimate of 5,000 kg/h, the segment would burn 5,000/15 ≈ 333 kg of fuel. Adjusting slightly downward for probable weight reduction and late segment, a value near 320 kg is reasonable.',
#      fuel_kg=320.0
#  ),
#  Prediction(
#      reasoning='The segment describes an A359 in level cruise flight at 38,000 ft for about 4 minutes. The altitude is steady (no vertical maneuver), and the groundspeed is stable around 456 knots. In cruise, efficient aircraft like the A350 typically burn about 2,300-2,700 kg/hour (depending on weight and location in the cruise). At the beginning of a long cruise, a higher weight increases burn. Over 4.015 minutes (0.0669 hours), with a higher end estimate (first part of cruise), approximate fuel burn is 2,700 kg/h * 0.0669 ≈ 181 kg. This segment is reasonably consistent and typical for level cruise.',
#      fuel_kg=181.0
#  ),
#  Prediction(
#      reasoning='This segment lasts about 4 minutes (4.02 min) and takes place at cruise altitude (38,000 ft) with very stable parameters: vertical rate remains near zero for 100% of time, groundspeed is steady (453 knots mean, very small change), and the aircraft type is an A359, a widebody long-haul aircraft. Fuel burn at cruise is much lower per minute than at climb or takeoff due to optimal height/speed. The A350-900 typically burns around 5,500 to 6,000 kg/hour in cruise with a moderate load. Since 4 minutes is about 1/15th of an hour, estimated fuel burn is (5,800 kg/hr * 4/60), about 387 kg. Consider that the plane, possibly still heavier near the start of cruise, might burn slightly more — but telemetry shows very steady state, so use a slight bump from base rate for realism.',
#      fuel_kg=400.0
#  ),
#  Prediction(
#      reasoning="The flight segment provided is for an Airbus A350-900 (A359) in the cruise phase at a steady altitude of approximately 38,000 feet. The vertical rate balance confirms stable level flight (near_zero_frac = 1.0), and the groundspeed is stable around 452–455 knots. The segment duration is just 4 minutes (0.06675 hours). During cruise, the A350 typically burns about 5,500–6,000 kg/hr under full load, but as the flight progresses and the aircraft gets lighter, this could drop somewhat. For a very short, level segment at cruise, I'll estimate fuel burn at the lower bound: 5,500 kg/hr × 0.06675 hr ≈ 367 kg, and further reduce slightly (to account for lighter weight midway through cruise), giving approximately 350 kg.",
#      fuel_kg=350.0
#  ),
#  Prediction(
#      reasoning='The segment shows cruise phase for an Airbus A350-900 at about 38,000 ft, with minimal altitude change (delta -5 ft) and groundspeed stable around 450 knots. The duration is about 4 minutes. The vertical rate is consistently near zero, showing level flight (cruise). For a modern A359 in cruise, typical fuel burn is approximately 2.2–2.5 metric tons per hour (2200–2500 kg/hr) per engine, but total for both engines is around 5,000 kg/hr. For 4.015 minutes, the burn is (5000 kg/hr) * (4.015/60 hr) ≈ 334 kg.',
#      fuel_kg=334.0
#  ),
#  Prediction(
#      reasoning="The flight segment is on an Airbus A350-900 (A359) in cruise at approximately 38,000 ft with a stable altitude and groundspeed around 450 knots. The time interval is 4.016 minutes, with vertical rate indicating completely level flight (no climbs or descents). For a modern A359, typical cruise fuel burn is about 5,600-6,000 kg/hr (at max weights, somewhat less as the plane lightens throughout the flight). Given this is likely an early cruise segment (as high fuel weight penalty applies), I'll estimate near the higher end. The segment is 4.016/60 hours = 0.0669 hours. Using 5,800 kg/hr as the cruise burn: 0.0669 * 5800 ≈ 388 kg.",
#      fuel_kg=388.0
#  ),
#  Prediction(
#      reasoning='The segment is 4 minutes long during the climb phase for an A350-900, with altitude increasing from 38,000 to 39,000 ft. The vertical rate is dominantly positive (+0.58), confirming climb, with a typical cruise groundspeed around 450 knots. Fuel burn during climb is higher than in cruise, and at this high altitude, burn is above cruise but not at maximum climb rates (as much of the climb is near-zero VR). Expected average climb burn for a widebody like A359 at this stage is around 120-200 kg/min (heavy at the beginning but lightening). For 4 minutes (starting from high altitude, so on the lower end of climb fuel rate): estimated fuel burnt = 150 kg/min * 4 min.',
#      fuel_kg=600.0
#  ),
#  Prediction(
#      reasoning='This segment represents a stable cruise phase in an Airbus A350-900 (A359), with altitude remaining almost perfectly constant at around 39,000 feet and groundspeed averaging about 456 knots over a brief duration of about 4 minutes. The vertical rate is near zero throughout, confirming level flight, and the aircraft is likely relatively heavy but has already burned some fuel after departure. During cruise, typical fuel flow for an A359 is about 5,500–6,000 kg/hr (both engines combined), but can be slightly higher when the plane is heavier and slightly lower at high, efficient cruise. Four minutes is about 1/15th of an hour, so expected burn: (5,800 kg/hr) * (4/60) ≈ 387 kg. Rounding to account for slight variations and noise yields an estimate of approximately 390 kg for this cruise segment.',
#      fuel_kg=390.0
#  ),
#  Prediction(
#      reasoning='The segment covers approximately 4 minutes of cruise flight at a nearly constant altitude (mean 37,990 ft, delta only -5 feet) and constant groundspeed (mean 461.9 knots, range only 2 knots). Vertical rate is almost entirely near zero (near_zero_frac = 1.0), confirming stable cruise. The aircraft is a Boeing 787-9 (B789), a large twinjet, which burns about 5.5-6.5 metric tonnes (5,500–6,500 kg) of fuel per hour during cruise at maximum gross weight; this value decreases modestly as the aircraft gets lighter through the cruise, but for short segments over a few minutes, this is a negligible effect. For 4 minutes, this equates to 1/15th of an hour. Using the higher end (6,200 kg/hr) for a loaded B789: (6,200 kg/hr) * (4/60) = 413 kg. Taking into account the expected reduction after a few hours into cruise, the actual burn is likely a bit below this, say around 380-400 kg. Therefore, my estimate is 390 kg for this segment.',
#      fuel_kg=390.0
#  ),
#  Prediction(
#      reasoning="This segment is for a Boeing 787-9 (B789) at cruise altitude (mean altitude ~38,000 ft). It's a short time segment (about 4.13 minutes) during level flight phase. The groundspeed is stable at around 461 knots with minor variation. The vertical rate is near zero for most samples (almost 69%), with a small negative vertical rate indicating slight descent at the end (but only for a brief moment). Fuel burn rate for a B789 at cruise is typically around 5,500 to 6,000 kg/hr, but during cruise and especially in steady flight (as here), it's at the lower end. With heavy weight at the beginning of cruise, let's estimate around 100 kg/min fuel flow: 100 * 4.13 = 413 kg, reducing a little for the fact this is later in cruise and possibly slightly lower power. Considering a slight negative bias due to the descent at the end, I estimate fuel used at 395 kg for this segment.",
#      fuel_kg=395.0
#  ),
#  Prediction(
#      reasoning='This is a Boeing 787-9 (B789) in a descent segment from about 37,850 ft to 31,800 ft (~6,050 ft loss) over about 3.88 minutes. Grounds speed drops slightly (454 to 420 kts). The vertical rate is strongly negative (mostly descending), minimal climb or level. During descent, engines are at reduced thrust, and fuel burn is much lower than in climb or cruise. Given the heavy airliner mass (early in descent, likely still significant weight), but short segment and low thrust, fuel burned will be a small fraction of total hourly cruise burn (typically 5,500–6,000 kg/h). Over ~4 min (1/15 hour), and assuming reduced thrust gives about 30–40% of cruise fuel flow, estimate: 6000 * 0.35 = 2100 kg/h, over 0.065 hr: 2100*0.065 ≈ 137 kg. Adjust for heavy initial weight and slight variance, conservatively estimate ~140 kg.',
#      fuel_kg=140.0
#  ),
#  Prediction(
#      reasoning='The segment is a short (4 min) descent phase of a B789, with average altitude dropping from about 11,000 to below 10,000 ft and groundspeed slowly decreasing from 313 to 264 knots. Descent phase generally burns less fuel than cruise or climb, especially at relatively low altitudes and speeds. The vertical rate is mostly negative or zero, confirming consistent descent/slowing maneuver. Typical fuel flow for a B789 in descent is around 2,000–3,000 kg/h total (entire aircraft), so for a 4-min segment, estimated burn: (2,500 kg/h)*(4/60) ≈ 166.7 kg. No unusual fuel penalties expected, no holding or added drag indicated.',
#      fuel_kg=170.0
#  ),
#  Prediction(
#      reasoning='This segment is part of a descent phase for a Boeing 787-9 (B789), starting at about 9200 ft and descending to about 4500 ft over 4 minutes. The mean groundspeed is 254.6 knots, and the segment is not particularly long. During descent, engines are typically at low power, meaning fuel flow is significantly lower than during climb or cruise. For this aircraft, descent fuel flow is generally between 1200-2000 kg/hr total for both engines at these speeds and altitudes. Over 4 minutes (4/60 = 0.0667 hr), even at the upper end (2000 kg/hr), expected burn is 0.0667*2000=133 kg. However, at such relatively low altitudes and descent rates, with some near-zero vertical rate periods, mid-range estimates (~1,600 kg/hr) are sensible: 0.0667*1600 ≈ 107 kg.',
#      fuel_kg=107.0
#  ),
#  Prediction(
#      reasoning='The segment covers a cruise phase for a Boeing 787-9 (B789) at around 39,000 ft, lasting 4.04 minutes with very stable groundspeed (~460 knots) and altitude (mean 38,990 ft, negligible fluctuation). Vertical rate indicates 93% of time at near-zero vertical movement, suggesting efficient cruise flight. For cruise, typical B789 fuel burn is about 5,500-6,200 kg/hr depending on weight and conditions; however, given near-constant cruise, a mid-range estimate around 5,800 kg/hr is reasonable. For 4.04 minutes (4.04/60 ≈ 0.0673 hr), fuel burn is 5,800 * 0.0673 ≈ 390 kg. As this is an early segment, fuel weight is on heavier side, but duration is very short, so ~390 kg is a sound estimate.',
#      fuel_kg=390.0
#  ),
#  Prediction(
#      reasoning='The segment occurs during cruise at a stable altitude of about 39,000 ft, with nearly zero vertical rate for the entire segment (near_zero_frac = 1.0), indicating level flight (no climb or descent). The B787-9 at cruise burns fuel at a rate of roughly 5,400 kg/hour. The segment duration is about 4 minutes (3.96 min), or 0.066 hours. Multiplying the hourly rate by the duration: 5,400 kg/h * 0.066 h ≈ 356 kg. Since this is a very short, stable cruise segment with no large speed or altitude changes, this estimate is a reasonable reflection of typical fuel consumption for this aircraft type at this phase.',
#      fuel_kg=356.0
#  ),
#  Prediction(
#      reasoning="The segment represents a 4-minute stretch of cruise at a stable altitude of approximately 39,000 ft, with groundspeed averaging about 467 knots. The vertical rate is essentially zero throughout the segment (near_zero_frac = 1.0), indicating level flight and therefore no extra fuel penalty for climb or descent. The aircraft is a Boeing 787-9, a long-haul twinjet with typical cruise fuel flow. For a B787-9 in cruise, the fuel burn rate is generally between 2,200 and 2,600 kg per hour at high weights, and assuming heavier weights early in the journey, I'll use ~2,500 kg/h as the rate. For just over 4 minutes (4.007/60 ≈ 0.06678 hours), expected burn = 2,500 * 0.06678 ≈ 167 kg. Given the segment is standard cruise and data is not anomalous, I'll report this value.",
#      fuel_kg=167.0
#  ),
#  Prediction(
#      reasoning="This flight segment is for a Boeing 787-9 (B789) at cruise altitude (around 39,000 ft), covering just over 4 minutes of level flight. The vertical rate is nearly zero throughout, suggesting very steady cruise with almost no altitude changes. The groundspeed remains high (~469 knots). During cruise, the main determinants of fuel burn are aircraft type, cruise weight penalty (slightly higher at the start of a long flight), and duration. For a B789 at cruise, a typical fuel burn rate is approximately 5.5-6.0 metric tons per hour depending on weight and conditions. For 4 minutes, that's (6,000 kg/hour) * (4/60) = 400 kg if using the higher end, but considering initial cruise (heavy), I will use about 430 kg to give room for early heavier weight.",
#      fuel_kg=430.0
#  ),
#  Prediction(
#      reasoning="The segment is a short cruise (about 4 minutes) in a Boeing 787-9 (B789) at around 39,000 ft. The speed is stable around 460 knots and there is virtually no vertical movement (vertical rate is near zero throughout). The aircraft is at cruise altitude, which means fuel burn is efficient, not as high as during climb or descent. Typical cruise fuel flow for a B789 is about 5,000–5,500 kg/hr, or around 83–92 kg/min. Since the aircraft is near the beginning of the flight (from an international airport), it likely has a heavy load, so I'll use a value on the upper end, around 92 kg/min. For 4.004 minutes: 4.004 x 92 ≈ 368 kg.",
#      fuel_kg=368.0
#  ),
#  Prediction(
#      reasoning="This is a Boeing 787-9 (B789) in cruise phase at a high, steady altitude (mean ~39,000 ft), with groundspeed consistently at 458-460 knots. The segment is just about 4 minutes long, with nearly zero vertical rate throughout (steady level flight). At these conditions, a B789 typically burns approximately 5.5-6 tonnes (5500-6000 kg) of fuel per hour in cruise. For 4 minutes, that's about (6000/60)*4 = 400 kg. Segment is very steady, no climbs/descents, so no extra penalty.",
#      fuel_kg=400.0
#  ),
#  Prediction(
#      reasoning='The phase is cruise at a stable altitude (~39,900 ft) and stable groundspeed (~458 kt). The vertical rate is near zero for the whole segment, confirming level flight. The segment duration is short (~4 minutes). During cruise, a B789 typically burns around 2.3-2.6 metric tons of fuel per hour, depending on weight, speed, and cruise level. Four minutes is about 1/15 of an hour. Assuming a higher weight penalty at the start of cruise and long-haul scenario, I’ll use ~2,600 kg/hr as an upper estimate. Fuel burn: 2,600 kg/hr ÷ 15 ≈ 173 kg.',
#      fuel_kg=173.0
#  ),
#  Prediction(
#      reasoning="The aircraft is a Boeing 787-8 (B788) operating at cruise level (altitude 40,000 ft, stable throughout the segment) and steady cruise speed at Mach 0.85. The flight segment is about 4.9 minutes long ('track_points_compact'). In cruise at this altitude and Mach, a B788 typically burns around 2,300-2,500 kg/hr. For brief, level cruise segments such as this, weight doesn't change much so a middle estimate is appropriate. 4.9 minutes is about 0.0815 hours: 0.0815 hrs × 2400 kg/hr ≈ 196 kg. Accounting for possible minor variability due to load or atmospheric conditions, a rounded estimate is 200 kg.",
#      fuel_kg=200.0
#  ),
#  Prediction(
#      reasoning='The segment covers just over 5 minutes of flight at high cruise altitude (around 40,000 ft) and constant Mach 0.85, suggesting stable, efficient cruise. No significant climb or descent, as altitude delta is negligible. The aircraft type B788 (Boeing 787-8) typically burns about 5,000-6,000 kg per hour at cruise, but fuel use is a bit less late in the flight as the aircraft becomes lighter. Over 5.1 minutes: (5,500 kg/hr estimated average) * (5.095/60) ≈ 467 kg for this segment.',
#      fuel_kg=467.0
#  ),
#  Prediction(
#      reasoning="The segment describes a Boeing 787-8 (B788) cruising in level flight at FL400 (40,000 ft) and a constant Mach 0.85 for approximately 5.13 minutes. There is negligible altitude or speed change, indicating a cruise segment, which is typically highly fuel-efficient per distance. The distance covered can be roughly estimated from the change in latitude and longitude: Δlat ≈ 0.63, Δlon ≈ 0.33. The aircraft at cruise burns less fuel than during climb or descent. A typical fuel consumption rate for the 787-8 at cruise is about 2,400-2,700 kg/hr (often closer to 2,500 kg/hr at weight near the start of cruise; lighter at the end of cruise). For a 5.13 minute segment: (5.129/60) * 2500 ≈ 214 kg. Given possible slight overestimation (unknown whether it's heavy cruise start or closer to end), a reasonable estimate is around 210-220 kg.",
#      fuel_kg=215.0
#  ),
#  Prediction(
#      reasoning="The segment duration is about 15 minutes, at a steady cruising altitude of 40,000 ft. Aircraft type is Boeing 787-8 (B788), a modern, efficient wide-body airliner. The phase is 'level', indicating cruising flight with little to no altitude change and minimal vertical maneuvering.\n\nFor a 787 in cruise, fuel flow typically ranges from 5,000-6,500 kg/hr at max weights, and tapers down as the aircraft gets lighter. For a 15-minute segment (0.25 hr), the expected fuel burn is around 1,250-1,625 kg for average weights. Since this is only a segment and duration is a bit below typical hourly block-fuel assessments, a midpoint in this range is reasonable. Given the steadily high cruise, stable mach, and no climb or descent, I'll use a cruise burn estimate for a medium-long range segment, around 6,000 kg/hr × 0.25 ≈ 1,500 kg, but will pick a value a bit below that (as at 40k ft cruise, slightly lower fuel flow is expected).",
#      fuel_kg=1400.0
#  ),
#  Prediction(
#      reasoning="The flight segment is 25.19 minutes long with a Boeing 787-8 (B788) at a steady cruise altitude (40,000 ft, minimal altitude variation) and constant mach 0.84. The phase is level, so it's pure cruise, not climb or descent. B788 typical cruise fuel burn is around 5,500-6,000 kg/hr (depends on weight; as fuel is burnt, the aircraft lightens, so average is a little less than initial rate). For 25.19 minutes: 25.19/60 ≈ 0.4198 hours. Estimated fuel burn: 0.4198 * 5700 ≈ 2,393 kg.",
#      fuel_kg=2393.0
#  ),
#  Prediction(
#      reasoning="The aircraft is a Boeing 787-8 (B788) operating at cruise level (altitude 40,000 ft constant), for about 5 minutes (5.04 min). Speed is Mach 0.84-0.85 (typical for cruise). In cruise, the 787-8 at this altitude burns approximately 2,200-2,500 kg/hour. For a short segment of 5 minutes, fuel burn will be a fraction of that: \n\nFuel burn per minute ≈ 2,350 kg/hr ÷ 60 ≈ 39.2 kg/min. \n\nFor 5.036 minutes: 39.2 × 5.036 ≈ 197.34 kg.\n\nGiven the flight is likely early in the journey from Bogota (probably heavy), I'll use the upper part of the burn rate range, so fuel burn for this segment is around 200 kg.",
#      fuel_kg=200.0
#  ),
#  Prediction(
#      reasoning='The segment is flown at high altitude (40,000 ft) and in cruise (phase: level), with an almost steady mach number (0.85 to 0.84) and no significant altitude change. The aircraft is a Boeing 787-8, a modern and efficient twin-aisle jet. The segment duration is approximately 5.25 minutes. At cruise, a B788 typically burns between 2100-2500 kg/hr depending on weight, altitude, and specifics; since this is a short segment and cruise burn is relatively steady, I’ll use the mean value (let’s say 2300 kg/hr). For 5.25 min: (2300 kg/hr) × (5.25/60) = ~201 kg. Rounding for plausible uncertainties, the estimated fuel burnt is about 200 kg.',
#      fuel_kg=200.0
#  ),
#  Prediction(
#      reasoning="The segment covers approximately 4.8 minutes at cruise altitude (around FL400) and constant Mach 0.84 in a Boeing 787-8. The altitude change is minimal (about 500 ft), confirming level flight. Fuel burn during high-altitude cruise is relatively low for widebody aircraft, but the initial fuel state is likely still moderately heavy (since the origin is listed, though the segment is short). A typical cruise fuel burn rate for a B788 is around 2400-2600 kg/hr at heavy weights; I'll use an average of 2500 kg/hr. For 4.8 minutes: (2500/60) * 4.825 ≈ 201 kg.",
#      fuel_kg=201.0
#  ),
#  Prediction(
#      reasoning="The segment is flown by a Boeing 787-8 (B788) at cruise altitude (40,500 ft) and constant speed (Mach 0.84 to 0.85) over about 5.2 minutes. The phase is labeled as 'level,' indicating steady, efficient cruise (lower fuel burn per minute than climb or descent). The distance covered is roughly 0.48 degrees latitude and 0.63 degrees longitude, which translates to about 80-100 km at cruise. Typical B788 cruise fuel burn is about 2,200-2,400 kg/hr depending on weight; since this is just over 5 minutes (roughly 1/12 of an hour), expected burn would be between 183 and 200 kg.",
#      fuel_kg=190.0
#  ),
#  Prediction(
#      reasoning="This segment is roughly 5 minutes long at cruising altitude (around FL400, very high for a B788). The aircraft is in a 'level' phase, with only a slight gain in altitude (469 ft). The Mach number is steady at around 0.845, which is normal for cruise. Typically, a Boeing 787-8 (~B788) at cruise burns about 2200-2400 kg/hr (heavier at the start, lighter toward the end of cruise, but this is just a 5 minute slice). For 5 minutes: (2200 kg/hr) * (5/60) = about 183 kg. However, as the altitude is high (less air resistance, potentially slightly more efficient), but also at relatively high initial fuel weight (segment could be near start of cruise), so let's use midpoint (2300 kg/hr). Thus, 2300 * (5/60) ≈ 191.67 kg. As this is a short, steady cruise segment with typical parameters and no significant climb or descent, 190-200 kg is reasonable.",
#      fuel_kg=192.0
#  ),
#  Prediction(
#      reasoning="This is a Boeing 787-8 (B788) in a level flight phase, maintaining a steady altitude of approximately 40,980 ft for roughly 4.893 minutes at a consistent Mach 0.84. The distance covered in this segment is moderate based on the latitude and longitude changes (~0.48 deg lat/0.66 deg lon, which is about ~80 km, but actual segment duration is much shorter which suggests it is a sub-segment and not an entire cruise). During steady-state cruise at this altitude and Mach, fuel consumption is primarily driven by airframe weight, engines, and minimal vertical maneuvering penalties. Since the segment is only about 5 minutes, a reasonable estimate using Boeing 787-8 cruise burn rate (about 5400-6000 kg/hr at initial cruise weights, falling with weight over time), would yield: 5400/60 * 5 = 450 kg if fully loaded on cruise, or a bit less for reduced weight late in a flight; I'll use a slight reduction to 430 kg for realism.",
#      fuel_kg=430.0
#  ),
#  Prediction(
#      reasoning='This is a Boeing 787-8 (B788) segment at cruise altitude (~41,000 ft), lasting just over 5 minutes, with steady Mach (0.84-0.85), negligible altitude change, and steady heading. In cruise at this altitude and speed, the B788 typically burns about 2,300-2,500 kg/hr depending on weight and conditions. For an initial estimate, using 2,400 kg/hr: (2,400 kg/hr) * (5.036/60) = approximately 201 kg. Since this is towards the beginning of a segment (heavier plane), estimate should bias slightly higher within the range.',
#      fuel_kg=205.0
#  ),
#  Prediction(
#      reasoning='The aircraft is a Boeing 787-8 (B788) flying at cruise altitude (41,000 ft) and constant cruise Mach (0.85), over a short segment lasting about 5 minutes (5.038 min), with a level flight phase. For a B788 in cruise, typical fuel burn rates are about 2400-2700 kg/hour, but considering early in the flight (departed from Bogota, likely still relatively heavy), I will use a figure near the upper end, around 2700 kg/hour. For a 5.038 minute segment: (2700/60)*5.038 = approx 227 kg. Possible extra margin for heavy early segment, but duration is short, so 225-230 kg is reasonable.',
#      fuel_kg=228.0
#  ),
#  Prediction(
#      reasoning="The segment is about 10 minutes long at cruise altitude (41,000 ft) and mach 0.85, on a B788 (Boeing 787-8). Fuel burn in cruise for this aircraft is about 5.5 tons/hour under typical full-weight cruise, but this will decrease slightly as the plane burns fuel. The altitude and mach are essentially constant, suggesting steady state cruise with no climb or descent fuel penalty. A 10-minute (1/6th of an hour) segment would therefore burn about 5,500 kg / 6 ≈ 917 kg. Considering cruise is sometimes more efficient at higher altitudes but there's also weight to account for at the start of cruise, a reasonable estimate is approximately 900–950 kg.",
#      fuel_kg=930.0
#  ),
#  Prediction(
#      reasoning="The segment is flown by a Boeing 787-8 (B788) at a steady cruise altitude of 41,000 feet and constant Mach 0.85. The segment lasts approximately 5 minutes. Since the vertical_rate_balance is not provided but the altitude remains constant, this indicates stable level cruise. During cruise at this altitude and speed, estimated hourly fuel burn for a B788 is around 5,000 kg/hr. For a 5-minute segment, the fuel burnt would be (5,000 kg/hr)*(5/60) = about 417 kg, but considering some initial climb and descent are not present and the aircraft is lighter than at the start of cruise, actual burn may be slightly lower. I'll round the estimate accordingly.",
#      fuel_kg=415.0
#  ),
#  Prediction(
#      reasoning="This segment is a level cruise phase for an Airbus A350-900 at 40,000 ft (FL400), lasting about 15 minutes (0.25 hours), with mach speed around 0.85—typical long haul cruise conditions. The A359 has an average cruise fuel flow around 5,300–6,200 kg/hr depending on weight. However, in early cruise (aircraft heavier), slightly above-average burn is plausible, so let's use about 6,000 kg/hr. For 0.25 hours, expected fuel burn is 1,500 kg (6,000 kg/hr x 0.25 hr = 1,500 kg). Given there is no altitude change (steady level flight), this is reasonable for this segment length and phase.",
#      fuel_kg=1500.0
#  ),
#  Prediction(
#      reasoning='The aircraft is an Airbus A350-900 (A359) flying at a constant altitude of 40,000 ft (level cruise phase) for a period of about 30 minutes, at a mean Mach of 0.85. There is negligible change in altitude and the flight appears stable, so this is a typical long-haul cruise segment. The A359 generally burns 5,500-6,500 kg/h in cruise at typical long-haul weights, but fuel flow gradually reduces as the aircraft gets lighter during cruise. Given this is a 30-minute segment (0.5 hours), initial cruise burn could be around 3,250 kg, with slight reduction toward the end; a reasonable estimate factoring this would be slightly less. Factoring in a minor reduction for weight decrease, a sensible estimate for this segment is about 3,100 kg.',
#      fuel_kg=3100.0
#  ),
#  Prediction(
# ...
#      fuel_kg=0.0
#  ),
#  Prediction(
#      reasoning="There are no track points and the vertical rate data is missing, which makes it impossible to estimate the segment's duration, distance, or altitude profile. Since there is no movement data and the origin_destination field is also empty, it's likely this segment represents no actual flight (perhaps a missing or null segment). Therefore, the fuel burnt should be zero.",
#      fuel_kg=0.0
#  ),
#  Prediction(
#      reasoning="The aircraft is a Boeing 787-9 (B789), flying in the cruise phase for approximately 15 minutes (14.93 minutes). The altitude stays constant at nearly 38,000 ft, and vertical rate is essentially zero for the whole segment, indicating straight and level flight (cruise). The groundspeed averages 463 knots, which is typical for long-range cruise. For the B789, fuel burn in cruise at this stage (early to mid cruise, still relatively heavy) is roughly 5,000–6,500 kg/h, depending on weight. At the start of cruise, the fuel burn is a bit higher; for the middle of flight we can conservatively estimate about 6,000 kg/h. The segment is about 15 minutes: 6,000 * (15/60) = 1,500 kg. Considering stable flight and average weight, I estimate about 1,450–1,550 kg; I'll choose 1,480 kg as a reasonable average.",
#      fuel_kg=1480.0
#  ),
#  Prediction(
#      reasoning="The segment is 15 minutes long, flown at cruise altitude (around 38,000 ft, almost no altitude change) and constant mach 0.84, with groundspeed averaging about 485 knots. Vertical rate is nearly zero for 98% of the time, indicating very stable cruise/level flight. For a Boeing 787-9 (B789), typical cruise fuel burn is about 5,000–6,000 kg per hour; at the start of a long cruise the aircraft is heavier so let's use toward the upper end. 15 minutes is 0.25 hours, so expected burn is approximately 0.25 × 6,000 = 1,500 kg. Since it's a stable cruise with no altitude change or speed fluctuations, no additional penalties are needed.",
#      fuel_kg=1500.0
#  ),
#  Prediction(
#      reasoning="This is a 15 minute climb segment on a Boeing 787-9 (B789), departing from Bengaluru airport. The altitude climbs from 38,000 to 39,000 feet. Groundspeed is steady (~490 knots average), and Mach is stable at 0.845. Vertical rate is mostly near zero with some positive climb (+0.24), indicating a shallow, step climb to cruise altitude. For a widebody like the B789, fuel burn during the transition to initial cruise is elevated due to a heavy aircraft after takeoff, but this is a short, gentle climb with little vertical displacement (1,000 ft). Typical cruise burn for B789 is 2,300–2,500 kg/h; climb segments are usually higher (~3,000 kg/h) but since it's just a minor altitude change at cruise, a modest uplift over cruise rates is appropriate. Over 15 minutes: 2,500–3,000 kg/h × 0.25 h = 625–750 kg range. Given mostly level flight, lean towards the lower end.",
#      fuel_kg=670.0
#  ),
#  Prediction(
#      reasoning='The segment is a 15.6-minute cruise for a Boeing 787-9 (B789) at an average altitude of almost 39,000 ft and Mach 0.85. The vertical rate is essentially zero, indicating near-level flight (supported by the vertical_rate_balance and delta_altitude of just -25 ft), so we can assume steady-state cruise conditions. For a B789, typical cruise fuel flow is approximately 5,200-5,800 kg/hr, depending on weight, engines, and efficiency. At the start of cruise, the aircraft is heavier and burns more, but this relatively short segment (15.6 min = 0.26 hr) means the weight penalty is moderate. Using a fuel flow of roughly 5,600 kg/hr: 5,600 * 0.26 ≈ 1,456 kg. Given likely high initial weight and conservative estimate, a value between 1,400 and 1,500 kg is reasonable.',
#      fuel_kg=1450.0
#  ),
#  Prediction(
#      reasoning='This is a descent segment for a Boeing 787-9 over 14.4 minutes. The vertical rate is consistently negative (descent), and altitude drops steeply from ~39,000 ft to ~26,000 ft. Groundspeed and Mach decrease modestly (Mach 0.85 to 0.8), which signals a stabilized, relatively shallow descent after an initial higher descent rate. During descent, engines are throttled back so fuel consumption drops compared to climb or cruise, but because this is a heavy long-haul jet still at a relatively high altitude, the descent is not idle for the whole time. A B789 at the beginning of descent could burn around 2,000–2,500 kg/hr, and since the descent is 14.4 minutes (0.24 hrs), expected fuel burn is about 500–600 kg, potentially higher if more drag or step descent is required. Given descent from high cruise, overall fuel burn should be around 575 kg.',
#      fuel_kg=575.0
#  ),
#  Prediction(
#      reasoning='This is a 15 minute descent segment for a Boeing 787-9. The aircraft descends from about 26,000 ft to 5,700 ft (delta ~20,300 ft). Mean groundspeed decreases from 471 kt to 185 kt, implying deceleration and extended drag. The mean Mach is moderate (0.555), tapering off as the aircraft slows. Virtually all of the vertical rate samples are negative, as expected in a descent segment. In descent, engines are at low thrust, and fuel flow is considerably lower than during cruise or climb. For a wide-body like the B789 in descent, fuel burn is typically around 1,200-1,600 kg per hour for both engines combined, and could be lower on idle. In 15 minutes, at an average descent fuel flow of roughly 1,320 kg/h (estimate at intermediate weight), expected burn would be about 330 kg (1,320/4), possibly a bit higher with speed brakes and deceleration. Given the high initial speed and altitude, I estimate around 350 kg for this segment.',
#      fuel_kg=350.0
#  ),
#  Prediction(
#      reasoning='The aircraft is an A332 (Airbus A330-200) in cruise at a steady altitude of approximately 40,000 ft, with a constant groundspeed of about 424 kt and a Mach number averaging 0.8145. The segment duration is just 5 minutes. There is negligible vertical rate (fully level segment), indicating no additional fuel required for climbing or descending. During cruise, the A332 typically burns around 5,000–6,000 kg/hr, which translates to roughly 83–100 kg per minute. Accounting for the fact that the aircraft will be somewhat lighter during this segment than at the start of cruise (though the short segment means the penalty is modest), and the stable flight parameters, a reasonable estimate is on the lower end of the cruise range. Therefore, for 5 minutes, the fuel burn would be 5 x 90 kg = 450 kg.',
#      fuel_kg=450.0
#  ),
#  Prediction(
#      reasoning='This is an A332 on a 5-minute segment at stable cruise at FL400. All telemetry shows near-zero change: vertical rate is zero throughout (stable altitude with only noise-level variations), groundspeed is nearly constant at ~425 knots, and Mach at 0.817 (steady and typical for long-haul cruise). At FL400 in stable cruise, fuel flow for an A330-200 is typically around 5000–6000 kg/hr, with a slight reduction as fuel burns but negligible over such a short segment. 5 minutes is 1/12 of an hour, so fuel burn expected is approximately (5500 kg/hr)*(5/60) = ~458 kg, adjusted slightly downward (as the segment is likely after initial cruise climb, and the plane is lighter than at departure). No climb or descent fuel penalty, and stable numbers indicate this segment is typical mid-cruise.',
#      fuel_kg=450.0
#  ),
#  Prediction(
#      reasoning='The segment is 5 minutes long on an A332 (Airbus A330-200), which at FL400 (40,000 ft) and cruise Mach 0.81 is at normal cruise altitude and speed. All telemetry indicates nearly level flight (vertical_rate mean -0.6 ft/min, vertical_rate_balance near_zero_frac 1.0), with stable groundspeed and mach. The A332 at heavy long-haul weight typically burns around 2400-2700 kg/hr during cruise at altitude, with burn reducing slightly as the aircraft gets lighter, but over a 5-minute window this is negligible. For 5 minutes (5/60 = 0.0833 hours), estimated fuel burn would be 0.0833 x 2500 kg ≈ 208 kg. Telemetry and inputs do not indicate abnormal conditions.',
#      fuel_kg=208.0
#  ),
#  Prediction(
#      reasoning="This is a short cruise segment on an Airbus A330-200 (A332) at high altitude (around FL400, or 40,000 ft) over approximately 5 minutes (5.05 minutes). The groundspeed, altitude, and Mach all indicate a stable cruise: groundspeed is steady (429-431 knots), Mach number is between 0.809-0.812, and vertical rate is essentially zero for the entire segment (100% near-zero according to vertical_rate_balance). At cruise, the fuel burn for an A332 is roughly 2500-3000 kg per hour, but at high altitude and stable conditions, possibly slightly lower, say about 2500 kg/h. For 5.05 minutes (0.0842 hours), that's approximately 2500 * 0.0842 = 210.5 kg. Since the aircraft is still relatively heavy (likely not late in the flight given the origin), the fuel flow would not be at the late-cruise minimum. No major climb, descent, or speed changes increase or decrease the burn. So a reasonable estimate is around 210 kg burnt during this segment.",
#      fuel_kg=210.0
#  ),
#  Prediction(
#      reasoning='The phase is cruise at FL400, with a very steady altitude and near-zero vertical rates throughout the ~5 minute segment. Groundspeed is steady (~435 knots), and the Mach number is typical for an A332 at cruise (around 0.81). No climb or descent fuel penalty applies. At cruise, an A332 typically burns around 2.5-3.0 metric tons per hour at this altitude, but at FL400 and just a 5-minute segment, we use the lower end due to the high efficiency at such altitude. 5 minutes is 1/12th of an hour, so fuel burn ≈ 2500 kg/hr * (5/60) = ~208 kg.',
#      fuel_kg=208.0
#  ),
#  Prediction(
#      reasoning="The segment is 5 minutes long at stable cruise altitude (~40,000 ft), with negligible altitude or speed changes and a very steady Mach (0.8145 mean). Aircraft is an A332; typical cruise fuel burn is about 5,700-6,000 kg/hr at max gross weight, but for a short segment weight will only slightly decrease. There is no climbing or significant bank, so baseline cruise. For 5 mins: (5700 kg/hr) x (5/60) = 475 kg. Since the segment is near perfectly steady and the aircraft is not fully heavy (not stated as early cruise), I'll slightly round down.",
#      fuel_kg=470.0
#  ),
#  Prediction(
#      reasoning='This flight segment is in the descent phase in an Airbus A332, lasting 5 minutes with average altitude dropping from 40,020 ft to 36,010 ft (about 4000 ft descent). Mean groundspeed is 429 knots, and ground track distance is relatively short. Descent burns much less fuel than climb or cruise; engines are operating at reduced thrust (vertical rate mostly negative indicating sustained descent), which reduces fuel flow. For an A332 in descent, expected fuel flow is roughly 2,000-2,500 kg/hr per engine (2 engines), so approx 4,000-5,000 kg/hr total. For 5 minutes (5/60 = 0.083 hr), expected burn = 0.083 * 4,000–5,000 = 332–416 kg. Due to higher initial gross weight at start of descent, let’s estimate slightly above the lower bound. Small adjustments for possible idling and short level-off. ',
#      fuel_kg=370.0
#  ),
#  Prediction(
#      reasoning="This is a descent segment for an A332 (Airbus A330-200), lasting approximately 5 minutes. The altitude drops by about 8,100 ft, from ~36,000 ft to ~27,900 ft. During descent, engines throttle back, fuel consumption is considerably lower than during climb or cruise, but not zero due to bleed air, anti-ice, and maintaining engine idle thrust. Groundspeed is stable, averaging ~424 kt, and descent is continuous (vertical_rate_balance shows 69% negative vertical rate, very little climb). For this heavy twin-aisle airliner, typical descent fuel flow rates are on the order of 1,100-1,600 kg/hr per engine, but at nearly the start of descent with the aircraft still heavy from fuel. Assuming about 2,400-3,000 kg/hr total (idle + systems demands), over 5 minutes that's (3000/60)*5 = 250 kg total as a high estimate. Realistic, with reduced thrust, a little less: approximately 180-250 kg.",
#      fuel_kg=220.0
#  ),
#  Prediction(
#      reasoning="This segment is a 10-minute descent on an Airbus A330-200 from about 17,840 ft down to 7,826 ft, with a mean altitude of 12,150 ft. The speed decreases from 362 to 290 knots (mean 319.5 kts). The mach number drops from 0.605 to 0.434, indicating deceleration, and the descent rate is consistently negative (mean -980 fpm, with 79% of the samples descending). In descent, engines are at low power settings, fuel burn is much lower than in cruise or climb, and the aircraft is lighter at this segment's end. For a heavy A332 in descent, burn rates can range from 1,200 to 2,000 kg/hour (typically closer to 1,500 kg/h at this phase). Over 10 minutes (1/6th of an hour), this would result in about 200–350 kg of fuel burned. Given it's an early descent from mid-altitude, let's estimate on the higher end: about 270 kg.",
#      fuel_kg=270.0
#  ),
#  Prediction(
#      reasoning='This segment is the descent phase for an Airbus A330-200 (A332) lasting about 10 minutes, with a significant loss in altitude (from 7,826 ft down to about 2,000 ft, a delta of -5,837 ft). The velocity decreases from 290 to 172 knots, and vertical rate remains predominantly negative (indicative of continuous descent). During descent, fuel flow is much lower than cruise or climb, as engines typically operate at reduced throttle, potentially with some idle phases. Assuming the typical idle/descent burn for an A332 is approx 20-30% of cruise fuel flow, and cruise burn is around 2,300-2,600 kg/h per engine (~4,800-5,200 kg/h total). For 10 minutes: cruise would be 800-900 kg; descent, about 20-30% of this, gives ~170-270 kg, accounting for speed and aircraft still not at minimum landing weight at this stage. Adding a bit for high initial altitude, but not too much as speeds are modest.',
#      fuel_kg=220.0
#  ),
#  Prediction(
#      reasoning='This flight segment is on an Airbus A21N, covers approximately 15 minutes, and is a clear descent from 23,000 ft to about 8,375 ft (delta nearly 14,600 ft). The groundspeed drops significantly from 451 to 248 knots, and the vertical rate is distinctly negative (average -1139 ft/min), confirming descent. During descent, thrust is reduced compared to cruise and climb, but some power is still required for systems, drag, and, at times, level-off maneuvers (24% of the time is near-zero vertical rate, likely approach or vectoring). A21N has average descent fuel burns of around 900-1200 kg/hr, but the fuel flow declines as altitude and airspeed decrease. Over 15 minutes (0.25 hours), expected fuel burn in descent is typically between 225 and 350 kg, with a slight upward adjustment due to likely high drag, longer time held at lower altitudes, or non-continuous descent. Given all factors, I estimate about 290 kg of fuel burnt in this segment.',
#      fuel_kg=290.0
#  ),
#  Prediction(
#      reasoning="This segment covers about 22.74 minutes and is a descent phase for an A21N aircraft. The altitude drops from 8375 ft to effectively ground level (-75 ft), indicating almost the entire descent profile. Groundspeed decreases steadily from 248 to 92 knots, aligning with a stabilized approach and final phases. The vertical rate is predominantly negative (50%) or near zero (49%), confirming a controlled descent with periods of level-off or low vertical movement, probably during vectors or approach configuration. In descent, fuel burn is much lower than in climb or cruise due to reduced thrust settings and aircraft weight minimizing further with altitude loss. For a modern narrowbody like the A21N, typical fuel burn during descent can average 850–1000 kg/hour, but reduces further on the final approach as engines are throttled back. For nearly 23 minutes (about 0.38 hours), a fair estimate is around 350–400 kg fuel burned. Accounting for the early portion starting above 8000 ft and prolonged level segments, I'll select the higher end.",
#      fuel_kg=390.0
#  )]

# %% [markdown]
# ## Usage

# %%
for lm in [gpt_oss_120b]:
  cost = sum([x['cost'] for x in lm.history if x['cost'] is not None])
  print(cost)
